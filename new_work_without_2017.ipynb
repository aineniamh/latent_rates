# %% [markdown]
# **Table of Contents**
# <div id="toc"></div>

# %% [markdown]
# # IMPORTS

# %%
from ete3 import Tree
import collections
from collections import Counter
from Bio import AlignIO
from Bio import SeqIO
import numpy as np
import math
#import pandas as pd
#import matplotlib.pyplot as plt
from __future__ import division
from scipy.spatial import distance
#%matplotlib inline

# %% [markdown]
# # 1610 EARLY SAMPLES

# %%
fw = open('wout17/mar_2014_ob_seqs.fa','w')
with open("wout17/Makona_1610_genomes_2016-06-23.fa", "rU") as handle:
    for record in SeqIO.parse(handle, "fasta"):
        if record.id.split('|')[-1].startswith('2014-03'):
            fw.write('>{}\n{}\n'.format(record.id, record.seq))
fw.close()

# %% [markdown]
# Edited in geneious. Took all March 2014 samples from 1610 dataset. Manually extracted only CDS and fixed frameshift position. Then combined with the spliced 39 reference data set and removed the 2017 sequence. Realigned using geneious too. Exported doc as 'EBOV_CDS_splice_38_with_early_1610.fshift.aln.fa'.

# %% [markdown]
# # RAXML TREE

# %%
fw=open('wout17/EBOV_CDS_splice_38_with_early_1610.fshift.underscores.aln.fa','w')
with open('wout17/EBOV_CDS_splice_38_with_early_1610.aln.fa','r') as f:
    for l in f:
        l=l.rstrip('\n')
        l=l.replace('|','_')
        #l=l.replace('?','N')
        fw.write(l+'\n')
fw.close()

# %%
# %%bash
# cd wout17/
# rm RAxML_*
# raxmlHPC-PTHREADS -f a -x 12345 -p 12345 -\# 1000 -m GTRGAMMA -s EBOV_CDS_splice_38_with_early_1610.fshift.underscores.aln.fa -n raxml_rapid_spliced_cds_tree -o EBOV_AF272001_Mayinga_Yambuku_DRC_1976,EBOV_KC242801_deRoover_DRC_1976,EBOV_KC242791_Bonduni_Tandala_DRC_1977 -T 4
# Out:
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
# IMPORTANT WARNING: Alignment column 5104 contains only undetermined values which will be treated as missing data
#
#
# IMPORTANT WARNING: Sequences EBOV_KM034556_G3677_SierraLeone_G_Kailahun_KissiTeng_2014-05-26 and EBOV_KM233089_G3814_SierraLeone_G_Kailahun_Jawie_2014-06-15 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_KJ660346_Kissidougou-C15_Kissidougou_Guinea_2014-03-17 and EBOV_Kissidougou-C15_KJ660346_GIN_Kissidougou_2014-03-17 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_KC242799_13709_Kikwit_DRC_1995 and EBOV_KC242796_13625_Kikwit_DRC_1995 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_KC242798_1Ikot_Gabon_1996 and EBOV_KC242794_2Nza_Gabon_1996 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_KC242793_1Eko_Gabon_1996 and EBOV_KC242797_1Oba_Gabon_1996 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_KC242793_1Eko_Gabon_1996 and EBOV_KC242795_1Mbie_Gabon_1996 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_EM_079405_KR817180_GIN_Gueckedou_2014-03-28 and EBOV_EM_079408_KR817181_GIN_Gueckedou_2014-03-31 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_EM_079413_KR817184_GIN_Gueckedou_2014-03-31 and EBOV_EM_079414_KR817185_GIN_Gueckedou_2014-03-31 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_EM_079421_KR817186_GIN_Macenta_2014-03-30 and EBOV_EM_079423_KR817188_GIN_Macenta_2014-03-27 are exactly identical
#
#
# IMPORTANT WARNING: Sequences EBOV_EM_079421_KR817186_GIN_Macenta_2014-03-30 and EBOV_Gueckedou-C07_KJ660347_GIN_Gueckedou_2014-03-20 are exactly identical
#
# IMPORTANT WARNING
# Found 10 sequences that are exactly identical to other sequences in the alignment.
# Normally they should be excluded from the analysis.
#
#
# IMPORTANT WARNING
# Found 1 column that contains only undetermined values which will be treated as missing data.
# Normally these columns should be excluded from the analysis.
#
# An alignment file with undetermined columns and sequence duplicates removed has already
# been printed to file EBOV_CDS_splice_38_with_early_1610.fshift.underscores.aln.fa.reduced
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
# Alignment has 1 completely undetermined sites that will be automatically removed from the input data
#
#
# This is the RAxML Master Pthread
#
# This is RAxML Worker Pthread Number: 1
#
# This is RAxML Worker Pthread Number: 3
#
# This is RAxML Worker Pthread Number: 2
#
#
# This is RAxML version 8.2.11 released by Alexandros Stamatakis on June 2017.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 305 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 3.49%
#
# RAxML rapid bootstrapping and subsequent ML search
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
#
# Executing 1000 rapid bootstrap inferences and thereafter a thorough ML search
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 305
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-PTHREADS -f a -x 12345 -p 12345 -# 1000 -m GTRGAMMA -s EBOV_CDS_splice_38_with_early_1610.fshift.underscores.aln.fa -n raxml_rapid_spliced_cds_tree -o EBOV_AF272001_Mayinga_Yambuku_DRC_1976,EBOV_KC242801_deRoover_DRC_1976,EBOV_KC242791_Bonduni_Tandala_DRC_1977 -T 4
#
#
#
# Time for BS model parameter optimization 0.128497
# Bootstrap[0]: Time 0.441721 seconds, bootstrap likelihood -26472.245163, best rearrangement setting 13
# Bootstrap[1]: Time 0.263312 seconds, bootstrap likelihood -26366.876682, best rearrangement setting 13
# Bootstrap[2]: Time 0.330446 seconds, bootstrap likelihood -26306.347301, best rearrangement setting 12
# Bootstrap[3]: Time 0.330821 seconds, bootstrap likelihood -26011.628732, best rearrangement setting 15
# Bootstrap[4]: Time 0.306972 seconds, bootstrap likelihood -26517.495423, best rearrangement setting 10
# Bootstrap[5]: Time 0.361447 seconds, bootstrap likelihood -26654.854375, best rearrangement setting 10
# Bootstrap[6]: Time 0.292014 seconds, bootstrap likelihood -26523.008866, best rearrangement setting 6
# Bootstrap[7]: Time 0.284459 seconds, bootstrap likelihood -26317.168315, best rearrangement setting 14
# Bootstrap[8]: Time 0.262359 seconds, bootstrap likelihood -26277.880815, best rearrangement setting 5
# Bootstrap[9]: Time 0.287724 seconds, bootstrap likelihood -26400.483243, best rearrangement setting 7
# Bootstrap[10]: Time 0.299319 seconds, bootstrap likelihood -26593.797003, best rearrangement setting 7
# Bootstrap[11]: Time 0.246489 seconds, bootstrap likelihood -26499.994815, best rearrangement setting 5
# Bootstrap[12]: Time 0.125894 seconds, bootstrap likelihood -26586.403559, best rearrangement setting 8
# Bootstrap[13]: Time 0.338773 seconds, bootstrap likelihood -26563.230406, best rearrangement setting 7
# Bootstrap[14]: Time 0.290532 seconds, bootstrap likelihood -26588.013055, best rearrangement setting 12
# Bootstrap[15]: Time 0.306820 seconds, bootstrap likelihood -26337.121688, best rearrangement setting 15
# Bootstrap[16]: Time 0.128253 seconds, bootstrap likelihood -26327.416837, best rearrangement setting 12
# Bootstrap[17]: Time 0.284542 seconds, bootstrap likelihood -26201.188462, best rearrangement setting 12
# Bootstrap[18]: Time 0.239512 seconds, bootstrap likelihood -26327.399016, best rearrangement setting 5
# Bootstrap[19]: Time 0.332406 seconds, bootstrap likelihood -26544.707129, best rearrangement setting 8
# Bootstrap[20]: Time 0.340657 seconds, bootstrap likelihood -26555.760385, best rearrangement setting 10
# Bootstrap[21]: Time 0.307840 seconds, bootstrap likelihood -26493.969063, best rearrangement setting 6
# Bootstrap[22]: Time 0.275958 seconds, bootstrap likelihood -26354.627488, best rearrangement setting 5
# Bootstrap[23]: Time 0.344871 seconds, bootstrap likelihood -26421.813914, best rearrangement setting 7
# Bootstrap[24]: Time 0.358848 seconds, bootstrap likelihood -26744.926345, best rearrangement setting 8
# Bootstrap[25]: Time 0.320930 seconds, bootstrap likelihood -26247.178171, best rearrangement setting 6
# Bootstrap[26]: Time 0.300573 seconds, bootstrap likelihood -26341.346864, best rearrangement setting 12
# Bootstrap[27]: Time 0.314909 seconds, bootstrap likelihood -26486.352878, best rearrangement setting 10
# Bootstrap[28]: Time 0.284399 seconds, bootstrap likelihood -26645.844447, best rearrangement setting 11
# Bootstrap[29]: Time 0.341026 seconds, bootstrap likelihood -26458.507246, best rearrangement setting 12
# Bootstrap[30]: Time 0.302864 seconds, bootstrap likelihood -26456.858263, best rearrangement setting 15
# Bootstrap[31]: Time 0.293877 seconds, bootstrap likelihood -26709.958835, best rearrangement setting 15
# Bootstrap[32]: Time 0.304985 seconds, bootstrap likelihood -26371.934564, best rearrangement setting 6
# Bootstrap[33]: Time 0.302356 seconds, bootstrap likelihood -26620.792215, best rearrangement setting 15
# Bootstrap[34]: Time 0.293466 seconds, bootstrap likelihood -26075.267007, best rearrangement setting 11
# Bootstrap[35]: Time 0.305051 seconds, bootstrap likelihood -26530.246086, best rearrangement setting 8
# Bootstrap[36]: Time 0.288387 seconds, bootstrap likelihood -26151.512898, best rearrangement setting 9
# Bootstrap[37]: Time 0.358006 seconds, bootstrap likelihood -26457.436386, best rearrangement setting 11
# Bootstrap[38]: Time 0.279706 seconds, bootstrap likelihood -26171.747730, best rearrangement setting 8
# Bootstrap[39]: Time 0.308811 seconds, bootstrap likelihood -26467.289509, best rearrangement setting 13
# Bootstrap[40]: Time 0.368260 seconds, bootstrap likelihood -26483.971777, best rearrangement setting 13
# Bootstrap[41]: Time 0.310542 seconds, bootstrap likelihood -26457.577379, best rearrangement setting 10
# Bootstrap[42]: Time 0.244406 seconds, bootstrap likelihood -26230.127639, best rearrangement setting 5
# Bootstrap[43]: Time 0.372019 seconds, bootstrap likelihood -26224.429510, best rearrangement setting 14
# Bootstrap[44]: Time 0.298458 seconds, bootstrap likelihood -26582.911414, best rearrangement setting 10
# Bootstrap[45]: Time 0.345411 seconds, bootstrap likelihood -26255.762808, best rearrangement setting 15
# Bootstrap[46]: Time 0.359107 seconds, bootstrap likelihood -26472.030585, best rearrangement setting 14
# Bootstrap[47]: Time 0.306931 seconds, bootstrap likelihood -26620.511403, best rearrangement setting 8
# Bootstrap[48]: Time 0.299317 seconds, bootstrap likelihood -26464.517592, best rearrangement setting 6
# Bootstrap[49]: Time 0.286617 seconds, bootstrap likelihood -26378.062840, best rearrangement setting 7
# Bootstrap[50]: Time 0.315948 seconds, bootstrap likelihood -26381.127214, best rearrangement setting 7
# Bootstrap[51]: Time 0.346652 seconds, bootstrap likelihood -26295.362003, best rearrangement setting 11
# Bootstrap[52]: Time 0.333072 seconds, bootstrap likelihood -26438.811381, best rearrangement setting 12
# Bootstrap[53]: Time 0.298450 seconds, bootstrap likelihood -26542.905205, best rearrangement setting 8
# Bootstrap[54]: Time 0.300853 seconds, bootstrap likelihood -26630.251177, best rearrangement setting 9
# Bootstrap[55]: Time 0.295673 seconds, bootstrap likelihood -26592.517340, best rearrangement setting 11
# Bootstrap[56]: Time 0.250442 seconds, bootstrap likelihood -26471.639357, best rearrangement setting 5
# Bootstrap[57]: Time 0.291066 seconds, bootstrap likelihood -26388.076919, best rearrangement setting 7
# Bootstrap[58]: Time 0.343014 seconds, bootstrap likelihood -26591.298079, best rearrangement setting 10
# Bootstrap[59]: Time 0.300923 seconds, bootstrap likelihood -25954.037063, best rearrangement setting 9
# Bootstrap[60]: Time 0.265127 seconds, bootstrap likelihood -26360.629565, best rearrangement setting 7
# Bootstrap[61]: Time 0.259956 seconds, bootstrap likelihood -26333.207786, best rearrangement setting 5
# Bootstrap[62]: Time 0.332673 seconds, bootstrap likelihood -26624.391759, best rearrangement setting 11
# Bootstrap[63]: Time 0.295338 seconds, bootstrap likelihood -26716.747431, best rearrangement setting 12
# Bootstrap[64]: Time 0.289894 seconds, bootstrap likelihood -26597.041919, best rearrangement setting 7
# Bootstrap[65]: Time 0.254942 seconds, bootstrap likelihood -26578.321682, best rearrangement setting 5
# Bootstrap[66]: Time 0.264167 seconds, bootstrap likelihood -26660.625110, best rearrangement setting 5
# Bootstrap[67]: Time 0.289232 seconds, bootstrap likelihood -26335.524995, best rearrangement setting 15
# Bootstrap[68]: Time 0.347085 seconds, bootstrap likelihood -26580.437562, best rearrangement setting 11
# Bootstrap[69]: Time 0.259534 seconds, bootstrap likelihood -26806.354938, best rearrangement setting 5
# Bootstrap[70]: Time 0.267301 seconds, bootstrap likelihood -26397.129971, best rearrangement setting 8
# Bootstrap[71]: Time 0.305525 seconds, bootstrap likelihood -26328.183751, best rearrangement setting 10
# Bootstrap[72]: Time 0.282782 seconds, bootstrap likelihood -26419.988556, best rearrangement setting 11
# Bootstrap[73]: Time 0.343503 seconds, bootstrap likelihood -26346.694864, best rearrangement setting 9
# Bootstrap[74]: Time 0.262364 seconds, bootstrap likelihood -26352.912762, best rearrangement setting 5
# Bootstrap[75]: Time 0.300340 seconds, bootstrap likelihood -26512.410363, best rearrangement setting 8
# Bootstrap[76]: Time 0.328358 seconds, bootstrap likelihood -26572.036188, best rearrangement setting 9
# Bootstrap[77]: Time 0.298577 seconds, bootstrap likelihood -26635.654962, best rearrangement setting 11
# Bootstrap[78]: Time 0.122224 seconds, bootstrap likelihood -26647.217899, best rearrangement setting 15
# Bootstrap[79]: Time 0.306116 seconds, bootstrap likelihood -26940.076446, best rearrangement setting 9
# Bootstrap[80]: Time 0.363976 seconds, bootstrap likelihood -26550.058400, best rearrangement setting 15
# Bootstrap[81]: Time 0.273211 seconds, bootstrap likelihood -26574.814264, best rearrangement setting 7
# Bootstrap[82]: Time 0.281367 seconds, bootstrap likelihood -26488.879570, best rearrangement setting 6
# Bootstrap[83]: Time 0.295478 seconds, bootstrap likelihood -26691.821118, best rearrangement setting 10
# Bootstrap[84]: Time 0.326771 seconds, bootstrap likelihood -26362.619133, best rearrangement setting 11
# Bootstrap[85]: Time 0.278746 seconds, bootstrap likelihood -26414.041058, best rearrangement setting 8
# Bootstrap[86]: Time 0.328706 seconds, bootstrap likelihood -26758.057494, best rearrangement setting 7
# Bootstrap[87]: Time 0.277885 seconds, bootstrap likelihood -26534.425066, best rearrangement setting 7
# Bootstrap[88]: Time 0.280660 seconds, bootstrap likelihood -26104.406463, best rearrangement setting 12
# Bootstrap[89]: Time 0.283248 seconds, bootstrap likelihood -26559.717552, best rearrangement setting 10
# Bootstrap[90]: Time 0.292409 seconds, bootstrap likelihood -26117.134437, best rearrangement setting 8
# Bootstrap[91]: Time 0.300671 seconds, bootstrap likelihood -26653.914149, best rearrangement setting 12
# Bootstrap[92]: Time 0.333958 seconds, bootstrap likelihood -26779.805014, best rearrangement setting 13
# Bootstrap[93]: Time 0.131980 seconds, bootstrap likelihood -26567.795120, best rearrangement setting 15
# Bootstrap[94]: Time 0.119641 seconds, bootstrap likelihood -26816.908403, best rearrangement setting 5
# Bootstrap[95]: Time 0.108810 seconds, bootstrap likelihood -26743.938013, best rearrangement setting 5
# Bootstrap[96]: Time 0.319079 seconds, bootstrap likelihood -27143.676210, best rearrangement setting 13
# Bootstrap[97]: Time 0.289755 seconds, bootstrap likelihood -26181.203486, best rearrangement setting 11
# Bootstrap[98]: Time 0.274240 seconds, bootstrap likelihood -26538.884220, best rearrangement setting 6
# Bootstrap[99]: Time 0.288593 seconds, bootstrap likelihood -26338.503073, best rearrangement setting 14
# Bootstrap[100]: Time 0.312821 seconds, bootstrap likelihood -26307.388583, best rearrangement setting 12
# Bootstrap[101]: Time 0.310818 seconds, bootstrap likelihood -26466.516857, best rearrangement setting 10
# Bootstrap[102]: Time 0.286831 seconds, bootstrap likelihood -26308.369710, best rearrangement setting 8
# Bootstrap[103]: Time 0.307807 seconds, bootstrap likelihood -26543.016389, best rearrangement setting 8
# Bootstrap[104]: Time 0.340174 seconds, bootstrap likelihood -26640.574587, best rearrangement setting 15
# Bootstrap[105]: Time 0.278041 seconds, bootstrap likelihood -26608.322444, best rearrangement setting 7
# Bootstrap[106]: Time 0.271679 seconds, bootstrap likelihood -26514.869270, best rearrangement setting 6
# Bootstrap[107]: Time 0.288056 seconds, bootstrap likelihood -25975.749629, best rearrangement setting 13
# Bootstrap[108]: Time 0.298509 seconds, bootstrap likelihood -26390.313738, best rearrangement setting 14
# Bootstrap[109]: Time 0.360080 seconds, bootstrap likelihood -26590.486387, best rearrangement setting 12
# Bootstrap[110]: Time 0.270317 seconds, bootstrap likelihood -26294.253849, best rearrangement setting 7
# Bootstrap[111]: Time 0.363725 seconds, bootstrap likelihood -26607.520369, best rearrangement setting 15
# Bootstrap[112]: Time 0.306974 seconds, bootstrap likelihood -26354.687745, best rearrangement setting 14
# Bootstrap[113]: Time 0.258486 seconds, bootstrap likelihood -26809.779443, best rearrangement setting 5
# Bootstrap[114]: Time 0.285482 seconds, bootstrap likelihood -26709.021135, best rearrangement setting 6
# Bootstrap[115]: Time 0.333312 seconds, bootstrap likelihood -26480.634332, best rearrangement setting 7
# Bootstrap[116]: Time 0.331622 seconds, bootstrap likelihood -26440.719135, best rearrangement setting 11
# Bootstrap[117]: Time 0.305757 seconds, bootstrap likelihood -26381.689649, best rearrangement setting 8
# Bootstrap[118]: Time 0.356010 seconds, bootstrap likelihood -26554.113448, best rearrangement setting 9
# Bootstrap[119]: Time 0.281354 seconds, bootstrap likelihood -26550.229991, best rearrangement setting 14
# Bootstrap[120]: Time 0.289769 seconds, bootstrap likelihood -26646.431768, best rearrangement setting 12
# Bootstrap[121]: Time 0.283872 seconds, bootstrap likelihood -26477.670238, best rearrangement setting 8
# Bootstrap[122]: Time 0.281480 seconds, bootstrap likelihood -26591.863208, best rearrangement setting 9
# Bootstrap[123]: Time 0.122648 seconds, bootstrap likelihood -26525.395738, best rearrangement setting 6
# Bootstrap[124]: Time 0.135231 seconds, bootstrap likelihood -26629.612164, best rearrangement setting 11
# Bootstrap[125]: Time 0.125138 seconds, bootstrap likelihood -26417.675159, best rearrangement setting 11
# Bootstrap[126]: Time 0.095375 seconds, bootstrap likelihood -26289.785482, best rearrangement setting 12
# Bootstrap[127]: Time 0.315425 seconds, bootstrap likelihood -26551.431188, best rearrangement setting 9
# Bootstrap[128]: Time 0.301074 seconds, bootstrap likelihood -26458.961689, best rearrangement setting 11
# Bootstrap[129]: Time 0.247159 seconds, bootstrap likelihood -26342.229523, best rearrangement setting 5
# Bootstrap[130]: Time 0.349096 seconds, bootstrap likelihood -26499.398048, best rearrangement setting 10
# Bootstrap[131]: Time 0.352593 seconds, bootstrap likelihood -26314.128817, best rearrangement setting 9
# Bootstrap[132]: Time 0.291337 seconds, bootstrap likelihood -26290.594233, best rearrangement setting 14
# Bootstrap[133]: Time 0.341648 seconds, bootstrap likelihood -26343.185917, best rearrangement setting 13
# Bootstrap[134]: Time 0.259675 seconds, bootstrap likelihood -26501.237447, best rearrangement setting 6
# Bootstrap[135]: Time 0.347533 seconds, bootstrap likelihood -26644.179166, best rearrangement setting 11
# Bootstrap[136]: Time 0.390278 seconds, bootstrap likelihood -26535.917354, best rearrangement setting 13
# Bootstrap[137]: Time 0.297787 seconds, bootstrap likelihood -26686.492367, best rearrangement setting 6
# Bootstrap[138]: Time 0.364307 seconds, bootstrap likelihood -26264.736856, best rearrangement setting 15
# Bootstrap[139]: Time 0.277752 seconds, bootstrap likelihood -26656.789892, best rearrangement setting 5
# Bootstrap[140]: Time 0.339792 seconds, bootstrap likelihood -26510.078912, best rearrangement setting 13
# Bootstrap[141]: Time 0.232449 seconds, bootstrap likelihood -26571.831113, best rearrangement setting 5
# Bootstrap[142]: Time 0.291947 seconds, bootstrap likelihood -26215.983464, best rearrangement setting 15
# Bootstrap[143]: Time 0.340715 seconds, bootstrap likelihood -26209.291855, best rearrangement setting 7
# Bootstrap[144]: Time 0.298418 seconds, bootstrap likelihood -26421.808044, best rearrangement setting 13
# Bootstrap[145]: Time 0.288291 seconds, bootstrap likelihood -26323.577807, best rearrangement setting 7
# Bootstrap[146]: Time 0.288040 seconds, bootstrap likelihood -26526.595200, best rearrangement setting 9
# Bootstrap[147]: Time 0.338827 seconds, bootstrap likelihood -26438.709280, best rearrangement setting 12
# Bootstrap[148]: Time 0.306119 seconds, bootstrap likelihood -26826.152649, best rearrangement setting 8
# Bootstrap[149]: Time 0.359266 seconds, bootstrap likelihood -26871.833397, best rearrangement setting 12
# Bootstrap[150]: Time 0.317009 seconds, bootstrap likelihood -26582.004684, best rearrangement setting 14
# Bootstrap[151]: Time 0.236746 seconds, bootstrap likelihood -26263.467622, best rearrangement setting 5
# Bootstrap[152]: Time 0.249692 seconds, bootstrap likelihood -26656.630468, best rearrangement setting 5
# Bootstrap[153]: Time 0.293549 seconds, bootstrap likelihood -26222.236882, best rearrangement setting 13
# Bootstrap[154]: Time 0.307117 seconds, bootstrap likelihood -26427.843445, best rearrangement setting 14
# Bootstrap[155]: Time 0.345605 seconds, bootstrap likelihood -26505.959897, best rearrangement setting 13
# Bootstrap[156]: Time 0.326433 seconds, bootstrap likelihood -26659.613390, best rearrangement setting 11
# Bootstrap[157]: Time 0.310861 seconds, bootstrap likelihood -26745.142124, best rearrangement setting 8
# Bootstrap[158]: Time 0.300289 seconds, bootstrap likelihood -25884.411471, best rearrangement setting 8
# Bootstrap[159]: Time 0.237969 seconds, bootstrap likelihood -26238.710262, best rearrangement setting 5
# Bootstrap[160]: Time 0.322567 seconds, bootstrap likelihood -26541.603400, best rearrangement setting 15
# Bootstrap[161]: Time 0.294053 seconds, bootstrap likelihood -26601.512069, best rearrangement setting 13
# Bootstrap[162]: Time 0.124963 seconds, bootstrap likelihood -26515.440729, best rearrangement setting 13
# Bootstrap[163]: Time 0.287125 seconds, bootstrap likelihood -26495.962912, best rearrangement setting 12
# Bootstrap[164]: Time 0.326293 seconds, bootstrap likelihood -26714.764476, best rearrangement setting 7
# Bootstrap[165]: Time 0.316493 seconds, bootstrap likelihood -26648.851305, best rearrangement setting 13
# Bootstrap[166]: Time 0.300612 seconds, bootstrap likelihood -26332.470167, best rearrangement setting 10
# Bootstrap[167]: Time 0.277604 seconds, bootstrap likelihood -26395.577636, best rearrangement setting 12
# Bootstrap[168]: Time 0.325325 seconds, bootstrap likelihood -26469.064266, best rearrangement setting 14
# Bootstrap[169]: Time 0.293775 seconds, bootstrap likelihood -26546.767244, best rearrangement setting 10
# Bootstrap[170]: Time 0.252750 seconds, bootstrap likelihood -26351.179388, best rearrangement setting 5
# Bootstrap[171]: Time 0.282229 seconds, bootstrap likelihood -26696.290475, best rearrangement setting 11
# Bootstrap[172]: Time 0.385537 seconds, bootstrap likelihood -26275.278999, best rearrangement setting 12
# Bootstrap[173]: Time 0.315033 seconds, bootstrap likelihood -26455.055179, best rearrangement setting 11
# Bootstrap[174]: Time 0.289309 seconds, bootstrap likelihood -26685.329964, best rearrangement setting 15
# Bootstrap[175]: Time 0.310085 seconds, bootstrap likelihood -26495.157247, best rearrangement setting 14
# Bootstrap[176]: Time 0.312092 seconds, bootstrap likelihood -26711.633123, best rearrangement setting 8
# Bootstrap[177]: Time 0.327546 seconds, bootstrap likelihood -26516.926056, best rearrangement setting 8
# Bootstrap[178]: Time 0.374949 seconds, bootstrap likelihood -26461.292588, best rearrangement setting 14
# Bootstrap[179]: Time 0.271062 seconds, bootstrap likelihood -26467.141259, best rearrangement setting 5
# Bootstrap[180]: Time 0.348369 seconds, bootstrap likelihood -26596.331850, best rearrangement setting 12
# Bootstrap[181]: Time 0.385541 seconds, bootstrap likelihood -26533.645681, best rearrangement setting 14
# Bootstrap[182]: Time 0.267222 seconds, bootstrap likelihood -26634.508563, best rearrangement setting 7
# Bootstrap[183]: Time 0.347993 seconds, bootstrap likelihood -26430.103318, best rearrangement setting 11
# Bootstrap[184]: Time 0.303368 seconds, bootstrap likelihood -26306.438855, best rearrangement setting 15
# Bootstrap[185]: Time 0.283062 seconds, bootstrap likelihood -26404.607150, best rearrangement setting 8
# Bootstrap[186]: Time 0.297684 seconds, bootstrap likelihood -26428.019417, best rearrangement setting 13
# Bootstrap[187]: Time 0.297414 seconds, bootstrap likelihood -26211.647166, best rearrangement setting 8
# Bootstrap[188]: Time 0.371226 seconds, bootstrap likelihood -26606.077628, best rearrangement setting 12
# Bootstrap[189]: Time 0.122854 seconds, bootstrap likelihood -26399.124358, best rearrangement setting 11
# Bootstrap[190]: Time 0.365010 seconds, bootstrap likelihood -26292.908926, best rearrangement setting 15
# Bootstrap[191]: Time 0.326601 seconds, bootstrap likelihood -26903.121098, best rearrangement setting 8
# Bootstrap[192]: Time 0.294590 seconds, bootstrap likelihood -26410.990458, best rearrangement setting 8
# Bootstrap[193]: Time 0.364061 seconds, bootstrap likelihood -26553.208206, best rearrangement setting 10
# Bootstrap[194]: Time 0.289379 seconds, bootstrap likelihood -26601.604286, best rearrangement setting 8
# Bootstrap[195]: Time 0.263287 seconds, bootstrap likelihood -26456.796509, best rearrangement setting 7
# Bootstrap[196]: Time 0.307973 seconds, bootstrap likelihood -26534.123122, best rearrangement setting 11
# Bootstrap[197]: Time 0.306707 seconds, bootstrap likelihood -26375.319391, best rearrangement setting 8
# Bootstrap[198]: Time 0.334747 seconds, bootstrap likelihood -26562.474450, best rearrangement setting 15
# Bootstrap[199]: Time 0.317118 seconds, bootstrap likelihood -26444.266706, best rearrangement setting 8
# Bootstrap[200]: Time 0.320324 seconds, bootstrap likelihood -26505.705501, best rearrangement setting 12
# Bootstrap[201]: Time 0.309732 seconds, bootstrap likelihood -26675.183497, best rearrangement setting 10
# Bootstrap[202]: Time 0.354962 seconds, bootstrap likelihood -26624.987152, best rearrangement setting 12
# Bootstrap[203]: Time 0.123240 seconds, bootstrap likelihood -26247.650594, best rearrangement setting 9
# Bootstrap[204]: Time 0.296457 seconds, bootstrap likelihood -26344.628807, best rearrangement setting 7
# Bootstrap[205]: Time 0.300980 seconds, bootstrap likelihood -26386.679138, best rearrangement setting 8
# Bootstrap[206]: Time 0.302166 seconds, bootstrap likelihood -26465.651752, best rearrangement setting 15
# Bootstrap[207]: Time 0.290769 seconds, bootstrap likelihood -26722.366144, best rearrangement setting 10
# Bootstrap[208]: Time 0.315750 seconds, bootstrap likelihood -26222.561614, best rearrangement setting 15
# Bootstrap[209]: Time 0.335161 seconds, bootstrap likelihood -26756.620969, best rearrangement setting 15
# Bootstrap[210]: Time 0.313235 seconds, bootstrap likelihood -26358.705845, best rearrangement setting 8
# Bootstrap[211]: Time 0.312320 seconds, bootstrap likelihood -26644.743650, best rearrangement setting 8
# Bootstrap[212]: Time 0.231975 seconds, bootstrap likelihood -26160.330334, best rearrangement setting 5
# Bootstrap[213]: Time 0.132826 seconds, bootstrap likelihood -26674.213970, best rearrangement setting 6
# Bootstrap[214]: Time 0.302012 seconds, bootstrap likelihood -26555.758426, best rearrangement setting 13
# Bootstrap[215]: Time 0.282461 seconds, bootstrap likelihood -26645.271365, best rearrangement setting 6
# Bootstrap[216]: Time 0.378958 seconds, bootstrap likelihood -26438.155153, best rearrangement setting 13
# Bootstrap[217]: Time 0.279230 seconds, bootstrap likelihood -26368.348304, best rearrangement setting 8
# Bootstrap[218]: Time 0.351407 seconds, bootstrap likelihood -26494.217262, best rearrangement setting 12
# Bootstrap[219]: Time 0.275305 seconds, bootstrap likelihood -26567.302930, best rearrangement setting 6
# Bootstrap[220]: Time 0.319580 seconds, bootstrap likelihood -26518.402442, best rearrangement setting 8
# Bootstrap[221]: Time 0.308669 seconds, bootstrap likelihood -26704.030331, best rearrangement setting 13
# Bootstrap[222]: Time 0.245746 seconds, bootstrap likelihood -26113.056518, best rearrangement setting 6
# Bootstrap[223]: Time 0.307026 seconds, bootstrap likelihood -26718.224140, best rearrangement setting 10
# Bootstrap[224]: Time 0.292968 seconds, bootstrap likelihood -26594.556212, best rearrangement setting 11
# Bootstrap[225]: Time 0.357479 seconds, bootstrap likelihood -26576.574309, best rearrangement setting 13
# Bootstrap[226]: Time 0.320138 seconds, bootstrap likelihood -26425.664373, best rearrangement setting 7
# Bootstrap[227]: Time 0.302893 seconds, bootstrap likelihood -26683.157816, best rearrangement setting 9
# Bootstrap[228]: Time 0.389400 seconds, bootstrap likelihood -26475.988260, best rearrangement setting 13
# Bootstrap[229]: Time 0.307631 seconds, bootstrap likelihood -26461.890456, best rearrangement setting 9
# Bootstrap[230]: Time 0.300623 seconds, bootstrap likelihood -26709.735885, best rearrangement setting 15
# Bootstrap[231]: Time 0.354493 seconds, bootstrap likelihood -27123.778752, best rearrangement setting 12
# Bootstrap[232]: Time 0.283074 seconds, bootstrap likelihood -26496.664177, best rearrangement setting 15
# Bootstrap[233]: Time 0.142764 seconds, bootstrap likelihood -26529.621514, best rearrangement setting 12
# Bootstrap[234]: Time 0.119375 seconds, bootstrap likelihood -26392.398243, best rearrangement setting 6
# Bootstrap[235]: Time 0.319469 seconds, bootstrap likelihood -26667.883506, best rearrangement setting 15
# Bootstrap[236]: Time 0.314790 seconds, bootstrap likelihood -26769.951122, best rearrangement setting 9
# Bootstrap[237]: Time 0.237921 seconds, bootstrap likelihood -26872.677324, best rearrangement setting 5
# Bootstrap[238]: Time 0.347356 seconds, bootstrap likelihood -26622.460018, best rearrangement setting 11
# Bootstrap[239]: Time 0.299039 seconds, bootstrap likelihood -26393.710134, best rearrangement setting 14
# Bootstrap[240]: Time 0.360474 seconds, bootstrap likelihood -26311.299623, best rearrangement setting 13
# Bootstrap[241]: Time 0.332563 seconds, bootstrap likelihood -26493.092339, best rearrangement setting 13
# Bootstrap[242]: Time 0.293663 seconds, bootstrap likelihood -26902.200944, best rearrangement setting 9
# Bootstrap[243]: Time 0.299550 seconds, bootstrap likelihood -26320.776019, best rearrangement setting 14
# Bootstrap[244]: Time 0.260467 seconds, bootstrap likelihood -26854.779090, best rearrangement setting 5
# Bootstrap[245]: Time 0.274529 seconds, bootstrap likelihood -26565.022085, best rearrangement setting 6
# Bootstrap[246]: Time 0.267785 seconds, bootstrap likelihood -26604.297310, best rearrangement setting 5
# Bootstrap[247]: Time 0.373939 seconds, bootstrap likelihood -26490.323640, best rearrangement setting 13
# Bootstrap[248]: Time 0.280356 seconds, bootstrap likelihood -26238.750714, best rearrangement setting 10
# Bootstrap[249]: Time 0.287413 seconds, bootstrap likelihood -26209.995658, best rearrangement setting 7
# Bootstrap[250]: Time 0.284766 seconds, bootstrap likelihood -26530.600061, best rearrangement setting 7
# Bootstrap[251]: Time 0.311106 seconds, bootstrap likelihood -26666.222070, best rearrangement setting 15
# Bootstrap[252]: Time 0.306245 seconds, bootstrap likelihood -26653.450710, best rearrangement setting 6
# Bootstrap[253]: Time 0.285328 seconds, bootstrap likelihood -26375.708480, best rearrangement setting 9
# Bootstrap[254]: Time 0.323069 seconds, bootstrap likelihood -26354.375524, best rearrangement setting 9
# Bootstrap[255]: Time 0.305627 seconds, bootstrap likelihood -26128.231355, best rearrangement setting 8
# Bootstrap[256]: Time 0.311213 seconds, bootstrap likelihood -26665.928126, best rearrangement setting 15
# Bootstrap[257]: Time 0.304043 seconds, bootstrap likelihood -26375.972699, best rearrangement setting 9
# Bootstrap[258]: Time 0.326314 seconds, bootstrap likelihood -26394.937908, best rearrangement setting 11
# Bootstrap[259]: Time 0.306802 seconds, bootstrap likelihood -26504.290544, best rearrangement setting 12
# Bootstrap[260]: Time 0.311577 seconds, bootstrap likelihood -26550.907890, best rearrangement setting 6
# Bootstrap[261]: Time 0.248555 seconds, bootstrap likelihood -26722.948621, best rearrangement setting 5
# Bootstrap[262]: Time 0.264281 seconds, bootstrap likelihood -26543.839431, best rearrangement setting 10
# Bootstrap[263]: Time 0.349176 seconds, bootstrap likelihood -26416.080870, best rearrangement setting 13
# Bootstrap[264]: Time 0.343331 seconds, bootstrap likelihood -26377.731380, best rearrangement setting 11
# Bootstrap[265]: Time 0.146810 seconds, bootstrap likelihood -26234.104129, best rearrangement setting 10
# Bootstrap[266]: Time 0.273888 seconds, bootstrap likelihood -26115.652510, best rearrangement setting 7
# Bootstrap[267]: Time 0.278916 seconds, bootstrap likelihood -26103.504398, best rearrangement setting 11
# Bootstrap[268]: Time 0.301690 seconds, bootstrap likelihood -26712.997483, best rearrangement setting 12
# Bootstrap[269]: Time 0.295980 seconds, bootstrap likelihood -26523.322422, best rearrangement setting 14
# Bootstrap[270]: Time 0.268745 seconds, bootstrap likelihood -26334.676512, best rearrangement setting 6
# Bootstrap[271]: Time 0.123667 seconds, bootstrap likelihood -26434.998923, best rearrangement setting 11
# Bootstrap[272]: Time 0.235887 seconds, bootstrap likelihood -26234.286481, best rearrangement setting 5
# Bootstrap[273]: Time 0.371179 seconds, bootstrap likelihood -26114.856079, best rearrangement setting 10
# Bootstrap[274]: Time 0.309313 seconds, bootstrap likelihood -26440.574965, best rearrangement setting 9
# Bootstrap[275]: Time 0.348849 seconds, bootstrap likelihood -26941.144621, best rearrangement setting 12
# Bootstrap[276]: Time 0.286744 seconds, bootstrap likelihood -26251.185590, best rearrangement setting 10
# Bootstrap[277]: Time 0.304815 seconds, bootstrap likelihood -26511.115690, best rearrangement setting 8
# Bootstrap[278]: Time 0.125754 seconds, bootstrap likelihood -26468.747177, best rearrangement setting 14
# Bootstrap[279]: Time 0.245843 seconds, bootstrap likelihood -26449.506549, best rearrangement setting 5
# Bootstrap[280]: Time 0.263838 seconds, bootstrap likelihood -26480.583156, best rearrangement setting 7
# Bootstrap[281]: Time 0.328688 seconds, bootstrap likelihood -26920.003783, best rearrangement setting 10
# Bootstrap[282]: Time 0.303202 seconds, bootstrap likelihood -26001.713687, best rearrangement setting 12
# Bootstrap[283]: Time 0.292682 seconds, bootstrap likelihood -26380.255557, best rearrangement setting 7
# Bootstrap[284]: Time 0.249460 seconds, bootstrap likelihood -26850.409299, best rearrangement setting 5
# Bootstrap[285]: Time 0.285608 seconds, bootstrap likelihood -26362.582332, best rearrangement setting 6
# Bootstrap[286]: Time 0.291036 seconds, bootstrap likelihood -26809.102608, best rearrangement setting 15
# Bootstrap[287]: Time 0.247095 seconds, bootstrap likelihood -26614.791700, best rearrangement setting 5
# Bootstrap[288]: Time 0.261045 seconds, bootstrap likelihood -26142.548028, best rearrangement setting 13
# Bootstrap[289]: Time 0.126492 seconds, bootstrap likelihood -26840.977402, best rearrangement setting 6
# Bootstrap[290]: Time 0.304727 seconds, bootstrap likelihood -26300.079232, best rearrangement setting 7
# Bootstrap[291]: Time 0.134460 seconds, bootstrap likelihood -26777.978857, best rearrangement setting 11
# Bootstrap[292]: Time 0.281915 seconds, bootstrap likelihood -26420.563769, best rearrangement setting 6
# Bootstrap[293]: Time 0.348814 seconds, bootstrap likelihood -26388.837661, best rearrangement setting 8
# Bootstrap[294]: Time 0.297612 seconds, bootstrap likelihood -26425.520402, best rearrangement setting 12
# Bootstrap[295]: Time 0.122452 seconds, bootstrap likelihood -26500.225229, best rearrangement setting 15
# Bootstrap[296]: Time 0.294029 seconds, bootstrap likelihood -26367.002022, best rearrangement setting 14
# Bootstrap[297]: Time 0.280269 seconds, bootstrap likelihood -26207.975610, best rearrangement setting 10
# Bootstrap[298]: Time 0.311003 seconds, bootstrap likelihood -26654.419625, best rearrangement setting 13
# Bootstrap[299]: Time 0.289005 seconds, bootstrap likelihood -26344.870718, best rearrangement setting 13
# Bootstrap[300]: Time 0.337394 seconds, bootstrap likelihood -26417.296333, best rearrangement setting 11
# Bootstrap[301]: Time 0.300117 seconds, bootstrap likelihood -26361.064003, best rearrangement setting 15
# Bootstrap[302]: Time 0.313870 seconds, bootstrap likelihood -26751.313968, best rearrangement setting 13
# Bootstrap[303]: Time 0.308291 seconds, bootstrap likelihood -26568.630908, best rearrangement setting 11
# Bootstrap[304]: Time 0.297471 seconds, bootstrap likelihood -26693.993420, best rearrangement setting 9
# Bootstrap[305]: Time 0.222442 seconds, bootstrap likelihood -26482.026385, best rearrangement setting 5
# Bootstrap[306]: Time 0.314892 seconds, bootstrap likelihood -26636.272504, best rearrangement setting 12
# Bootstrap[307]: Time 0.296964 seconds, bootstrap likelihood -26214.461164, best rearrangement setting 9
# Bootstrap[308]: Time 0.290815 seconds, bootstrap likelihood -26542.963182, best rearrangement setting 11
# Bootstrap[309]: Time 0.284355 seconds, bootstrap likelihood -26273.908417, best rearrangement setting 9
# Bootstrap[310]: Time 0.297310 seconds, bootstrap likelihood -26656.404303, best rearrangement setting 7
# Bootstrap[311]: Time 0.320836 seconds, bootstrap likelihood -26359.151207, best rearrangement setting 7
# Bootstrap[312]: Time 0.311048 seconds, bootstrap likelihood -26563.073572, best rearrangement setting 8
# Bootstrap[313]: Time 0.321066 seconds, bootstrap likelihood -26890.589463, best rearrangement setting 13
# Bootstrap[314]: Time 0.290746 seconds, bootstrap likelihood -26720.867249, best rearrangement setting 8
# Bootstrap[315]: Time 0.274126 seconds, bootstrap likelihood -26220.372461, best rearrangement setting 5
# Bootstrap[316]: Time 0.311304 seconds, bootstrap likelihood -26404.717532, best rearrangement setting 10
# Bootstrap[317]: Time 0.289440 seconds, bootstrap likelihood -26420.290953, best rearrangement setting 10
# Bootstrap[318]: Time 0.128156 seconds, bootstrap likelihood -26746.193394, best rearrangement setting 14
# Bootstrap[319]: Time 0.139944 seconds, bootstrap likelihood -26839.829814, best rearrangement setting 10
# Bootstrap[320]: Time 0.307366 seconds, bootstrap likelihood -26345.017740, best rearrangement setting 13
# Bootstrap[321]: Time 0.277836 seconds, bootstrap likelihood -26591.921167, best rearrangement setting 13
# Bootstrap[322]: Time 0.145130 seconds, bootstrap likelihood -26668.200164, best rearrangement setting 13
# Bootstrap[323]: Time 0.123209 seconds, bootstrap likelihood -26679.071238, best rearrangement setting 14
# Bootstrap[324]: Time 0.325312 seconds, bootstrap likelihood -26574.240273, best rearrangement setting 12
# Bootstrap[325]: Time 0.295082 seconds, bootstrap likelihood -26596.359608, best rearrangement setting 9
# Bootstrap[326]: Time 0.258999 seconds, bootstrap likelihood -26560.726644, best rearrangement setting 8
# Bootstrap[327]: Time 0.307649 seconds, bootstrap likelihood -26710.586847, best rearrangement setting 7
# Bootstrap[328]: Time 0.294784 seconds, bootstrap likelihood -26550.390811, best rearrangement setting 9
# Bootstrap[329]: Time 0.252982 seconds, bootstrap likelihood -26217.768104, best rearrangement setting 8
# Bootstrap[330]: Time 0.305421 seconds, bootstrap likelihood -26566.960821, best rearrangement setting 8
# Bootstrap[331]: Time 0.353279 seconds, bootstrap likelihood -26659.724363, best rearrangement setting 13
# Bootstrap[332]: Time 0.276505 seconds, bootstrap likelihood -26478.596776, best rearrangement setting 5
# Bootstrap[333]: Time 0.302678 seconds, bootstrap likelihood -26294.357139, best rearrangement setting 9
# Bootstrap[334]: Time 0.136866 seconds, bootstrap likelihood -26639.112448, best rearrangement setting 11
# Bootstrap[335]: Time 0.306968 seconds, bootstrap likelihood -26296.629309, best rearrangement setting 13
# Bootstrap[336]: Time 0.316787 seconds, bootstrap likelihood -26529.330831, best rearrangement setting 14
# Bootstrap[337]: Time 0.260802 seconds, bootstrap likelihood -26433.803198, best rearrangement setting 6
# Bootstrap[338]: Time 0.307762 seconds, bootstrap likelihood -26680.244079, best rearrangement setting 7
# Bootstrap[339]: Time 0.284871 seconds, bootstrap likelihood -26305.299961, best rearrangement setting 6
# Bootstrap[340]: Time 0.316037 seconds, bootstrap likelihood -26768.093605, best rearrangement setting 15
# Bootstrap[341]: Time 0.260113 seconds, bootstrap likelihood -26657.947327, best rearrangement setting 5
# Bootstrap[342]: Time 0.368901 seconds, bootstrap likelihood -26369.238130, best rearrangement setting 13
# Bootstrap[343]: Time 0.273322 seconds, bootstrap likelihood -26932.392524, best rearrangement setting 5
# Bootstrap[344]: Time 0.350410 seconds, bootstrap likelihood -26417.143252, best rearrangement setting 12
# Bootstrap[345]: Time 0.293019 seconds, bootstrap likelihood -26554.164432, best rearrangement setting 11
# Bootstrap[346]: Time 0.253946 seconds, bootstrap likelihood -26374.929655, best rearrangement setting 6
# Bootstrap[347]: Time 0.344066 seconds, bootstrap likelihood -26426.527381, best rearrangement setting 12
# Bootstrap[348]: Time 0.256419 seconds, bootstrap likelihood -26238.605741, best rearrangement setting 5
# Bootstrap[349]: Time 0.305588 seconds, bootstrap likelihood -26800.234157, best rearrangement setting 7
# Bootstrap[350]: Time 0.266063 seconds, bootstrap likelihood -26427.209250, best rearrangement setting 6
# Bootstrap[351]: Time 0.285242 seconds, bootstrap likelihood -26655.205509, best rearrangement setting 6
# Bootstrap[352]: Time 0.137681 seconds, bootstrap likelihood -26279.285626, best rearrangement setting 7
# Bootstrap[353]: Time 0.325107 seconds, bootstrap likelihood -26849.984280, best rearrangement setting 7
# Bootstrap[354]: Time 0.297361 seconds, bootstrap likelihood -26606.505959, best rearrangement setting 11
# Bootstrap[355]: Time 0.377424 seconds, bootstrap likelihood -26590.415204, best rearrangement setting 14
# Bootstrap[356]: Time 0.328015 seconds, bootstrap likelihood -26124.407825, best rearrangement setting 15
# Bootstrap[357]: Time 0.311232 seconds, bootstrap likelihood -26174.715249, best rearrangement setting 11
# Bootstrap[358]: Time 0.339821 seconds, bootstrap likelihood -26696.542142, best rearrangement setting 14
# Bootstrap[359]: Time 0.262594 seconds, bootstrap likelihood -26521.007294, best rearrangement setting 6
# Bootstrap[360]: Time 0.302155 seconds, bootstrap likelihood -26596.664122, best rearrangement setting 6
# Bootstrap[361]: Time 0.327413 seconds, bootstrap likelihood -26860.796652, best rearrangement setting 10
# Bootstrap[362]: Time 0.125661 seconds, bootstrap likelihood -26679.269378, best rearrangement setting 8
# Bootstrap[363]: Time 0.133774 seconds, bootstrap likelihood -26709.385179, best rearrangement setting 10
# Bootstrap[364]: Time 0.352306 seconds, bootstrap likelihood -26256.000307, best rearrangement setting 9
# Bootstrap[365]: Time 0.330380 seconds, bootstrap likelihood -26274.154563, best rearrangement setting 10
# Bootstrap[366]: Time 0.125088 seconds, bootstrap likelihood -26337.678742, best rearrangement setting 8
# Bootstrap[367]: Time 0.235104 seconds, bootstrap likelihood -26234.186183, best rearrangement setting 5
# Bootstrap[368]: Time 0.326271 seconds, bootstrap likelihood -26477.175057, best rearrangement setting 11
# Bootstrap[369]: Time 0.305088 seconds, bootstrap likelihood -26477.896409, best rearrangement setting 13
# Bootstrap[370]: Time 0.366176 seconds, bootstrap likelihood -26390.571268, best rearrangement setting 13
# Bootstrap[371]: Time 0.338325 seconds, bootstrap likelihood -26722.381613, best rearrangement setting 12
# Bootstrap[372]: Time 0.284295 seconds, bootstrap likelihood -26321.231245, best rearrangement setting 10
# Bootstrap[373]: Time 0.385253 seconds, bootstrap likelihood -26802.128483, best rearrangement setting 15
# Bootstrap[374]: Time 0.274875 seconds, bootstrap likelihood -26663.009060, best rearrangement setting 5
# Bootstrap[375]: Time 0.282614 seconds, bootstrap likelihood -26473.509866, best rearrangement setting 15
# Bootstrap[376]: Time 0.117284 seconds, bootstrap likelihood -26567.744455, best rearrangement setting 7
# Bootstrap[377]: Time 0.319293 seconds, bootstrap likelihood -26422.402114, best rearrangement setting 12
# Bootstrap[378]: Time 0.375503 seconds, bootstrap likelihood -26500.719875, best rearrangement setting 13
# Bootstrap[379]: Time 0.290036 seconds, bootstrap likelihood -26818.397798, best rearrangement setting 9
# Bootstrap[380]: Time 0.340424 seconds, bootstrap likelihood -26656.146137, best rearrangement setting 10
# Bootstrap[381]: Time 0.283179 seconds, bootstrap likelihood -26422.906751, best rearrangement setting 6
# Bootstrap[382]: Time 0.284854 seconds, bootstrap likelihood -25928.328564, best rearrangement setting 8
# Bootstrap[383]: Time 0.302639 seconds, bootstrap likelihood -26506.358861, best rearrangement setting 15
# Bootstrap[384]: Time 0.278676 seconds, bootstrap likelihood -26462.082642, best rearrangement setting 10
# Bootstrap[385]: Time 0.292032 seconds, bootstrap likelihood -26437.738512, best rearrangement setting 10
# Bootstrap[386]: Time 0.344321 seconds, bootstrap likelihood -26360.250064, best rearrangement setting 15
# Bootstrap[387]: Time 0.279978 seconds, bootstrap likelihood -26353.954067, best rearrangement setting 12
# Bootstrap[388]: Time 0.303263 seconds, bootstrap likelihood -26543.667827, best rearrangement setting 10
# Bootstrap[389]: Time 0.270546 seconds, bootstrap likelihood -26305.428198, best rearrangement setting 6
# Bootstrap[390]: Time 0.295302 seconds, bootstrap likelihood -26491.906513, best rearrangement setting 14
# Bootstrap[391]: Time 0.321742 seconds, bootstrap likelihood -26468.779578, best rearrangement setting 13
# Bootstrap[392]: Time 0.295594 seconds, bootstrap likelihood -26623.355213, best rearrangement setting 7
# Bootstrap[393]: Time 0.324602 seconds, bootstrap likelihood -26431.529359, best rearrangement setting 13
# Bootstrap[394]: Time 0.335889 seconds, bootstrap likelihood -26817.140211, best rearrangement setting 15
# Bootstrap[395]: Time 0.320807 seconds, bootstrap likelihood -26348.042165, best rearrangement setting 8
# Bootstrap[396]: Time 0.327351 seconds, bootstrap likelihood -26873.135260, best rearrangement setting 7
# Bootstrap[397]: Time 0.291685 seconds, bootstrap likelihood -26377.036993, best rearrangement setting 11
# Bootstrap[398]: Time 0.299180 seconds, bootstrap likelihood -26645.962739, best rearrangement setting 11
# Bootstrap[399]: Time 0.294524 seconds, bootstrap likelihood -26638.063777, best rearrangement setting 8
# Bootstrap[400]: Time 0.246007 seconds, bootstrap likelihood -26535.897486, best rearrangement setting 5
# Bootstrap[401]: Time 0.271161 seconds, bootstrap likelihood -26359.134526, best rearrangement setting 15
# Bootstrap[402]: Time 0.254828 seconds, bootstrap likelihood -26265.804110, best rearrangement setting 5
# Bootstrap[403]: Time 0.246506 seconds, bootstrap likelihood -26567.068523, best rearrangement setting 5
# Bootstrap[404]: Time 0.256106 seconds, bootstrap likelihood -26718.663555, best rearrangement setting 6
# Bootstrap[405]: Time 0.301304 seconds, bootstrap likelihood -26524.437948, best rearrangement setting 15
# Bootstrap[406]: Time 0.342221 seconds, bootstrap likelihood -26537.054984, best rearrangement setting 9
# Bootstrap[407]: Time 0.315059 seconds, bootstrap likelihood -26595.863829, best rearrangement setting 12
# Bootstrap[408]: Time 0.271476 seconds, bootstrap likelihood -26962.224415, best rearrangement setting 9
# Bootstrap[409]: Time 0.368586 seconds, bootstrap likelihood -26529.678406, best rearrangement setting 13
# Bootstrap[410]: Time 0.312304 seconds, bootstrap likelihood -26447.317560, best rearrangement setting 15
# Bootstrap[411]: Time 0.338923 seconds, bootstrap likelihood -26592.673946, best rearrangement setting 14
# Bootstrap[412]: Time 0.282869 seconds, bootstrap likelihood -26600.087992, best rearrangement setting 7
# Bootstrap[413]: Time 0.229191 seconds, bootstrap likelihood -26442.607217, best rearrangement setting 5
# Bootstrap[414]: Time 0.280406 seconds, bootstrap likelihood -26189.889638, best rearrangement setting 6
# Bootstrap[415]: Time 0.291400 seconds, bootstrap likelihood -26361.750140, best rearrangement setting 9
# Bootstrap[416]: Time 0.256534 seconds, bootstrap likelihood -26509.927434, best rearrangement setting 6
# Bootstrap[417]: Time 0.286721 seconds, bootstrap likelihood -26318.498404, best rearrangement setting 10
# Bootstrap[418]: Time 0.303649 seconds, bootstrap likelihood -26066.870709, best rearrangement setting 15
# Bootstrap[419]: Time 0.323170 seconds, bootstrap likelihood -26219.268385, best rearrangement setting 14
# Bootstrap[420]: Time 0.251742 seconds, bootstrap likelihood -26715.955445, best rearrangement setting 5
# Bootstrap[421]: Time 0.311155 seconds, bootstrap likelihood -26676.622659, best rearrangement setting 8
# ...
# Bootstrap[871]: Time 0.362084 seconds, bootstrap likelihood -26678.212611, best rearrangement setting 13
# Bootstrap[872]: Time 0.326757 seconds, bootstrap likelihood -26341.422322, best rearrangement setting 11
# Bootstrap[873]: Time 0.320928 seconds, bootstrap likelihood -26606.030484, best rearrangement setting 14
# Bootstrap[874]: Time 0.335258 seconds, bootstrap likelihood -26752.321631, best rearrangement setting 8
# Bootstrap[875]: Time 0.284887 seconds, bootstrap likelihood -26397.431607, best rearrangement setting 8
# Bootstrap[876]: Time 0.271557 seconds, bootstrap likelihood -26588.475666, best rearrangement setting 5
# Bootstrap[877]: Time 0.259252 seconds, bootstrap likelihood -27088.140948, best rearrangement setting 5
# Bootstrap[878]: Time 0.294621 seconds, bootstrap likelihood -26599.793923, best rearrangement setting 7
# Bootstrap[879]: Time 0.273688 seconds, bootstrap likelihood -26388.151988, best rearrangement setting 9
# Bootstrap[880]: Time 0.286853 seconds, bootstrap likelihood -26273.441113, best rearrangement setting 12
# Bootstrap[881]: Time 0.270793 seconds, bootstrap likelihood -26263.191397, best rearrangement setting 6
# Bootstrap[882]: Time 0.306124 seconds, bootstrap likelihood -26357.887951, best rearrangement setting 11
# Bootstrap[883]: Time 0.338069 seconds, bootstrap likelihood -26989.397632, best rearrangement setting 9
# Bootstrap[884]: Time 0.292291 seconds, bootstrap likelihood -26436.515707, best rearrangement setting 15
# Bootstrap[885]: Time 0.135501 seconds, bootstrap likelihood -26592.610364, best rearrangement setting 6
# Bootstrap[886]: Time 0.261106 seconds, bootstrap likelihood -26470.908591, best rearrangement setting 6
# Bootstrap[887]: Time 0.335341 seconds, bootstrap likelihood -26179.969588, best rearrangement setting 10
# Bootstrap[888]: Time 0.249707 seconds, bootstrap likelihood -26606.713602, best rearrangement setting 5
# Bootstrap[889]: Time 0.368108 seconds, bootstrap likelihood -26388.087656, best rearrangement setting 13
# Bootstrap[890]: Time 0.318728 seconds, bootstrap likelihood -26576.253072, best rearrangement setting 14
# Bootstrap[891]: Time 0.291722 seconds, bootstrap likelihood -26438.136213, best rearrangement setting 11
# Bootstrap[892]: Time 0.293692 seconds, bootstrap likelihood -26351.040383, best rearrangement setting 15
# Bootstrap[893]: Time 0.257890 seconds, bootstrap likelihood -26511.661682, best rearrangement setting 7
# Bootstrap[894]: Time 0.241639 seconds, bootstrap likelihood -26567.990751, best rearrangement setting 6
# Bootstrap[895]: Time 0.300330 seconds, bootstrap likelihood -26406.865810, best rearrangement setting 7
# Bootstrap[896]: Time 0.284956 seconds, bootstrap likelihood -26145.455372, best rearrangement setting 14
# Bootstrap[897]: Time 0.302232 seconds, bootstrap likelihood -26451.697798, best rearrangement setting 15
# Bootstrap[898]: Time 0.305561 seconds, bootstrap likelihood -26651.639612, best rearrangement setting 13
# Bootstrap[899]: Time 0.242878 seconds, bootstrap likelihood -26627.606789, best rearrangement setting 5
# Bootstrap[900]: Time 0.297741 seconds, bootstrap likelihood -26402.327779, best rearrangement setting 7
# Bootstrap[901]: Time 0.282625 seconds, bootstrap likelihood -26110.005764, best rearrangement setting 7
# Bootstrap[902]: Time 0.279643 seconds, bootstrap likelihood -26444.760159, best rearrangement setting 6
# Bootstrap[903]: Time 0.302989 seconds, bootstrap likelihood -26097.032361, best rearrangement setting 14
# Bootstrap[904]: Time 0.337844 seconds, bootstrap likelihood -26732.689616, best rearrangement setting 10
# Bootstrap[905]: Time 0.303800 seconds, bootstrap likelihood -26316.030575, best rearrangement setting 12
# Bootstrap[906]: Time 0.289649 seconds, bootstrap likelihood -26250.380208, best rearrangement setting 8
# Bootstrap[907]: Time 0.297052 seconds, bootstrap likelihood -26719.513540, best rearrangement setting 10
# Bootstrap[908]: Time 0.249924 seconds, bootstrap likelihood -26117.273024, best rearrangement setting 5
# Bootstrap[909]: Time 0.333900 seconds, bootstrap likelihood -26562.427783, best rearrangement setting 10
# Bootstrap[910]: Time 0.290478 seconds, bootstrap likelihood -26255.148563, best rearrangement setting 14
# Bootstrap[911]: Time 0.365602 seconds, bootstrap likelihood -26748.344563, best rearrangement setting 12
# Bootstrap[912]: Time 0.262137 seconds, bootstrap likelihood -26219.729727, best rearrangement setting 7
# Bootstrap[913]: Time 0.302389 seconds, bootstrap likelihood -26634.304150, best rearrangement setting 15
# Bootstrap[914]: Time 0.316732 seconds, bootstrap likelihood -26350.419519, best rearrangement setting 12
# Bootstrap[915]: Time 0.273061 seconds, bootstrap likelihood -26535.873958, best rearrangement setting 8
# Bootstrap[916]: Time 0.127822 seconds, bootstrap likelihood -26563.035026, best rearrangement setting 5
# Bootstrap[917]: Time 0.325116 seconds, bootstrap likelihood -26399.842954, best rearrangement setting 10
# Bootstrap[918]: Time 0.325217 seconds, bootstrap likelihood -26495.636212, best rearrangement setting 9
# Bootstrap[919]: Time 0.301795 seconds, bootstrap likelihood -26630.891242, best rearrangement setting 7
# Bootstrap[920]: Time 0.265874 seconds, bootstrap likelihood -26667.624108, best rearrangement setting 15
# Bootstrap[921]: Time 0.340769 seconds, bootstrap likelihood -26627.179695, best rearrangement setting 13
# Bootstrap[922]: Time 0.270317 seconds, bootstrap likelihood -26768.919574, best rearrangement setting 6
# Bootstrap[923]: Time 0.257076 seconds, bootstrap likelihood -26199.843325, best rearrangement setting 5
# Bootstrap[924]: Time 0.319430 seconds, bootstrap likelihood -26377.799136, best rearrangement setting 12
# Bootstrap[925]: Time 0.286613 seconds, bootstrap likelihood -26521.262658, best rearrangement setting 10
# Bootstrap[926]: Time 0.271822 seconds, bootstrap likelihood -26373.849706, best rearrangement setting 8
# Bootstrap[927]: Time 0.328217 seconds, bootstrap likelihood -26728.518966, best rearrangement setting 7
# Bootstrap[928]: Time 0.273678 seconds, bootstrap likelihood -26548.697212, best rearrangement setting 7
# Bootstrap[929]: Time 0.327141 seconds, bootstrap likelihood -26371.812674, best rearrangement setting 7
# Bootstrap[930]: Time 0.291394 seconds, bootstrap likelihood -26267.846813, best rearrangement setting 14
# Bootstrap[931]: Time 0.297417 seconds, bootstrap likelihood -26502.247898, best rearrangement setting 8
# Bootstrap[932]: Time 0.270504 seconds, bootstrap likelihood -26481.685613, best rearrangement setting 12
# Bootstrap[933]: Time 0.134730 seconds, bootstrap likelihood -26545.509916, best rearrangement setting 14
# Bootstrap[934]: Time 0.315707 seconds, bootstrap likelihood -26166.587273, best rearrangement setting 8
# Bootstrap[935]: Time 0.279061 seconds, bootstrap likelihood -26522.964322, best rearrangement setting 13
# Bootstrap[936]: Time 0.299477 seconds, bootstrap likelihood -26418.763416, best rearrangement setting 10
# Bootstrap[937]: Time 0.300717 seconds, bootstrap likelihood -26382.187205, best rearrangement setting 11
# Bootstrap[938]: Time 0.356758 seconds, bootstrap likelihood -26524.947543, best rearrangement setting 11
# Bootstrap[939]: Time 0.282870 seconds, bootstrap likelihood -26321.662325, best rearrangement setting 6
# Bootstrap[940]: Time 0.277876 seconds, bootstrap likelihood -26281.458111, best rearrangement setting 7
# Bootstrap[941]: Time 0.342239 seconds, bootstrap likelihood -26643.421213, best rearrangement setting 11
# Bootstrap[942]: Time 0.365713 seconds, bootstrap likelihood -26352.450335, best rearrangement setting 14
# Bootstrap[943]: Time 0.292933 seconds, bootstrap likelihood -26612.161490, best rearrangement setting 12
# Bootstrap[944]: Time 0.298537 seconds, bootstrap likelihood -26445.119829, best rearrangement setting 15
# Bootstrap[945]: Time 0.314138 seconds, bootstrap likelihood -26625.231323, best rearrangement setting 13
# Bootstrap[946]: Time 0.244103 seconds, bootstrap likelihood -26577.055641, best rearrangement setting 5
# Bootstrap[947]: Time 0.304715 seconds, bootstrap likelihood -26541.632246, best rearrangement setting 11
# Bootstrap[948]: Time 0.305187 seconds, bootstrap likelihood -26587.242040, best rearrangement setting 15
# Bootstrap[949]: Time 0.305717 seconds, bootstrap likelihood -26813.113714, best rearrangement setting 9
# Bootstrap[950]: Time 0.326117 seconds, bootstrap likelihood -26523.675774, best rearrangement setting 10
# Bootstrap[951]: Time 0.278977 seconds, bootstrap likelihood -26781.669194, best rearrangement setting 6
# Bootstrap[952]: Time 0.357565 seconds, bootstrap likelihood -26568.204638, best rearrangement setting 14
# Bootstrap[953]: Time 0.308890 seconds, bootstrap likelihood -26624.821830, best rearrangement setting 8
# Bootstrap[954]: Time 0.320358 seconds, bootstrap likelihood -26213.439372, best rearrangement setting 11
# Bootstrap[955]: Time 0.313071 seconds, bootstrap likelihood -26716.794236, best rearrangement setting 8
# Bootstrap[956]: Time 0.307144 seconds, bootstrap likelihood -26425.407472, best rearrangement setting 10
# Bootstrap[957]: Time 0.349865 seconds, bootstrap likelihood -26619.279677, best rearrangement setting 9
# Bootstrap[958]: Time 0.282825 seconds, bootstrap likelihood -26125.303449, best rearrangement setting 7
# Bootstrap[959]: Time 0.235510 seconds, bootstrap likelihood -26690.952236, best rearrangement setting 6
# Bootstrap[960]: Time 0.371656 seconds, bootstrap likelihood -26331.173534, best rearrangement setting 15
# Bootstrap[961]: Time 0.295765 seconds, bootstrap likelihood -26406.027561, best rearrangement setting 8
# Bootstrap[962]: Time 0.114886 seconds, bootstrap likelihood -26670.027637, best rearrangement setting 5
# Bootstrap[963]: Time 0.305063 seconds, bootstrap likelihood -26362.194264, best rearrangement setting 7
# Bootstrap[964]: Time 0.338623 seconds, bootstrap likelihood -26276.977927, best rearrangement setting 14
# Bootstrap[965]: Time 0.339585 seconds, bootstrap likelihood -26188.828671, best rearrangement setting 12
# Bootstrap[966]: Time 0.343697 seconds, bootstrap likelihood -26309.015981, best rearrangement setting 9
# Bootstrap[967]: Time 0.298928 seconds, bootstrap likelihood -26186.019779, best rearrangement setting 11
# Bootstrap[968]: Time 0.272669 seconds, bootstrap likelihood -26336.128424, best rearrangement setting 9
# Bootstrap[969]: Time 0.304017 seconds, bootstrap likelihood -26841.245820, best rearrangement setting 9
# Bootstrap[970]: Time 0.282874 seconds, bootstrap likelihood -26635.157925, best rearrangement setting 6
# Bootstrap[971]: Time 0.321928 seconds, bootstrap likelihood -26490.083890, best rearrangement setting 12
# Bootstrap[972]: Time 0.302250 seconds, bootstrap likelihood -26769.351440, best rearrangement setting 13
# Bootstrap[973]: Time 0.344901 seconds, bootstrap likelihood -25945.155326, best rearrangement setting 10
# Bootstrap[974]: Time 0.306618 seconds, bootstrap likelihood -26714.074227, best rearrangement setting 8
# Bootstrap[975]: Time 0.312921 seconds, bootstrap likelihood -26916.020531, best rearrangement setting 10
# Bootstrap[976]: Time 0.358319 seconds, bootstrap likelihood -26602.135562, best rearrangement setting 15
# Bootstrap[977]: Time 0.334881 seconds, bootstrap likelihood -26648.578182, best rearrangement setting 12
# Bootstrap[978]: Time 0.374663 seconds, bootstrap likelihood -26800.439665, best rearrangement setting 13
# Bootstrap[979]: Time 0.302400 seconds, bootstrap likelihood -26374.602693, best rearrangement setting 14
# Bootstrap[980]: Time 0.294729 seconds, bootstrap likelihood -26031.753366, best rearrangement setting 9
# Bootstrap[981]: Time 0.140421 seconds, bootstrap likelihood -26820.650589, best rearrangement setting 13
# Bootstrap[982]: Time 0.295711 seconds, bootstrap likelihood -26456.095750, best rearrangement setting 8
# Bootstrap[983]: Time 0.263438 seconds, bootstrap likelihood -26671.471754, best rearrangement setting 7
# Bootstrap[984]: Time 0.346042 seconds, bootstrap likelihood -26497.638703, best rearrangement setting 13
# Bootstrap[985]: Time 0.284091 seconds, bootstrap likelihood -26599.962977, best rearrangement setting 7
# Bootstrap[986]: Time 0.301393 seconds, bootstrap likelihood -26490.107863, best rearrangement setting 10
# Bootstrap[987]: Time 0.295100 seconds, bootstrap likelihood -26643.253611, best rearrangement setting 7
# Bootstrap[988]: Time 0.280382 seconds, bootstrap likelihood -26580.105401, best rearrangement setting 7
# Bootstrap[989]: Time 0.275024 seconds, bootstrap likelihood -26249.173807, best rearrangement setting 15
# Bootstrap[990]: Time 0.301302 seconds, bootstrap likelihood -26565.056921, best rearrangement setting 15
# Bootstrap[991]: Time 0.320199 seconds, bootstrap likelihood -26656.781297, best rearrangement setting 10
# Bootstrap[992]: Time 0.288707 seconds, bootstrap likelihood -26497.851164, best rearrangement setting 9
# Bootstrap[993]: Time 0.318359 seconds, bootstrap likelihood -26614.739721, best rearrangement setting 7
# Bootstrap[994]: Time 0.349836 seconds, bootstrap likelihood -26550.757583, best rearrangement setting 14
# Bootstrap[995]: Time 0.297801 seconds, bootstrap likelihood -26161.303589, best rearrangement setting 9
# Bootstrap[996]: Time 0.312131 seconds, bootstrap likelihood -26463.503963, best rearrangement setting 7
# Bootstrap[997]: Time 0.297328 seconds, bootstrap likelihood -26930.545276, best rearrangement setting 15
# Bootstrap[998]: Time 0.236772 seconds, bootstrap likelihood -26486.084680, best rearrangement setting 5
# Bootstrap[999]: Time 0.275291 seconds, bootstrap likelihood -26627.212067, best rearrangement setting 6
#
#
# Overall Time for 1000 Rapid Bootstraps 293.473783 seconds
# Average Time per Rapid Bootstrap 0.293474 seconds
#
# Starting ML Search ...
#
# Fast ML optimization finished
#
# Fast ML search Time: 82.433920 seconds
#
# Slow ML Search 0 Likelihood: -26534.033787
# Slow ML Search 1 Likelihood: -26534.033789
# Slow ML Search 2 Likelihood: -26534.033789
# Slow ML Search 3 Likelihood: -26534.033790
# Slow ML Search 4 Likelihood: -26534.033794
# Slow ML Search 5 Likelihood: -26534.033791
# Slow ML Search 6 Likelihood: -26534.033797
# Slow ML Search 7 Likelihood: -26534.033793
# Slow ML Search 8 Likelihood: -26534.033799
# Slow ML Search 9 Likelihood: -26534.033796
# Slow ML optimization finished
#
# Slow ML search Time: 6.183468 seconds
# Thorough ML search Time: 1.020623 seconds
#
# Final ML Optimization Likelihood: -26534.059011
#
# Model Information:
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 0.491047
# Tree-Length: 0.067382
# rate A <-> C: 1.469029
# rate A <-> G: 11.521538
# rate A <-> T: 0.915607
# rate C <-> G: 0.217459
# rate C <-> T: 13.924775
# rate G <-> T: 1.000000
#
# freq pi(A): 0.307905
# freq pi(C): 0.224848
# freq pi(G): 0.210979
# freq pi(T): 0.256268
#
#
# ML search took 89.641008 secs or 0.024900 hours
#
# Combined Bootstrap and ML search took 383.114858 secs or 0.106421 hours
#
# Drawing Bootstrap Support Values on best-scoring ML tree ...
#
#
#
# Found 1 tree in File /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bestTree.raxml_rapid_spliced_cds_tree
#
#
#
# Found 1 tree in File /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bestTree.raxml_rapid_spliced_cds_tree
#
# Program execution info written to /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_info.raxml_rapid_spliced_cds_tree
# All 1000 bootstrapped trees written to: /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bootstrap.raxml_rapid_spliced_cds_tree
#
# Best-scoring ML tree written to: /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bestTree.raxml_rapid_spliced_cds_tree
#
# Best-scoring ML tree with support values written to: /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree
#
# Best-scoring ML tree with support values as branch labels written to: /Users/aineniamhotoole/Google Drive/phd/latent_rates/wout17/RAxML_bipartitionsBranchLabels.raxml_rapid_spliced_cds_tree
#
# Overall execution time for full ML analysis: 383.367914 secs or 0.106491 hours or 0.004437 days

# %% [markdown]
# # NT AND CODON DICTS

# %%
n_dict = {
        'B':['C','G','T'],
        'D':['A','G','T'],
        'H':['A','C','T'],
        'K':['G','T'],
        'M':['C','A'],
        'N':['A','C','G','T'],
        'R':['A','G'],
        'S':['C','G'],
        'V':['A','C','G'],
        'W':['A','T'],
        'Y':['C','T'],
        'W':['A','T'],
        '?':['?']
    }

reverse_n_dict = {}

for k in n_dict:
    reverse_n_dict[''.join(sorted(n_dict[k]))]=k

codontable = {
    'ATA':'I', 'ATC':'I', 'ATT':'I', 'ATG':'M',
    'ACA':'T', 'ACC':'T', 'ACG':'T', 'ACT':'T',
    'AAC':'N', 'AAT':'N', 'AAA':'K', 'AAG':'K',
    'AGC':'S', 'AGT':'S', 'AGA':'R', 'AGG':'R',
    'CTA':'L', 'CTC':'L', 'CTG':'L', 'CTT':'L',
    'CCA':'P', 'CCC':'P', 'CCG':'P', 'CCT':'P',
    'CAC':'H', 'CAT':'H', 'CAA':'Q', 'CAG':'Q',
    'CGA':'R', 'CGC':'R', 'CGG':'R', 'CGT':'R',
    'GTA':'V', 'GTC':'V', 'GTG':'V', 'GTT':'V',
    'GCA':'A', 'GCC':'A', 'GCG':'A', 'GCT':'A',
    'GAC':'D', 'GAT':'D', 'GAA':'E', 'GAG':'E',
    'GGA':'G', 'GGC':'G', 'GGG':'G', 'GGT':'G',
    'TCA':'S', 'TCC':'S', 'TCG':'S', 'TCT':'S',
    'TTC':'F', 'TTT':'F', 'TTA':'L', 'TTG':'L',
    'TAC':'Y', 'TAT':'Y', 'TAA':'_', 'TAG':'_',
    'TGC':'C', 'TGT':'C', 'TGA':'_', 'TGG':'W',
    }

no_codons_per_aa=collections.Counter()
for i in codontable:
    no_codons_per_aa[codontable[i]]+=1

# %% [markdown]
# # GENE LOCATION DICT

# %%
gene={}
for i in range(1,2221):
    gene[i]="NP"
for i in range(2221,3244):
    gene[i]="VP35"
for i in range(3244,4225):
    gene[i]="VP40"
for i in range(4225,6256):
    gene[i]="GP"
for i in range(6256,7123):
    gene[i]="VP30"
for i in range(7123,7879):
    gene[i]="VP24"
for i in range(7879,14518):
    gene[i]="L"
print(len(gene))
fw = open('gene_location.csv','w')
fw.write('Position,Gene\n')
for k in gene:
    fw.write(('{},{}\n').format(k,gene[k]))
fw.close()
# Out:
# 14517

# %% [markdown]
# # FITCH ANCESTRAL RECONSTRUCTION

# %%
def deltran(my_tree):
    bases = []
    t2 = my_tree.copy()
    for node in t2.traverse("preorder"):
        if not node.is_root() and not node.is_leaf():
            if len(node.var)>1:
                dt = node.var.intersection(node.up.var)
                if dt:
                    node.var=dt
        if len(node.var)>1:
            node.var=set(reverse_n_dict[''.join(sorted(list(node.var)))])
        node.var = list(node.var)[0]
        bases.append((node.id, node.var))
#     print t2.get_ascii(attributes=["var","id"])  
    return bases

def acctran(my_tree):
    bases = []
    t3 = my_tree.copy()
    for node in t3.traverse("preorder"):
        if not node.is_root() and not node.is_leaf():
            if len(node.var)>1:
                at = node.var.difference(node.up.var)
                if at:
                    node.var=at
        
        if len(node.var)>1:
            node.var=set(reverse_n_dict[''.join(sorted(list(node.var)))])
        node.var = list(node.var)[0]
        bases.append((node.id, node.var))
#     print t3.get_ascii(attributes=["var","id"])  
    return bases


def fitch_algorithm(tree,nts,option):
    t = Tree(tree,format=1)
   
    changes_of_state = 0

    c=0
    for node in t.traverse("postorder"):
        c+=1
#         print node
        node.add_features(id=c)
        
        #add snp annotations to the tips of the tree
        if node.is_leaf(): 
            nt=nts[index_dict[node.name]]
            
            if nt in n_dict:
                node.add_features(var=set(n_dict[nt]))
            else:
                node.add_features(var=set(nt))

        if node.children:
            r = set(node.children[1].var)
            r = [n_dict[i] if i in n_dict else i for i in r] 
            r = set([x for sublist in r for x in sublist])
            
            l = set(node.children[0].var)
            l = [n_dict[i] if i in n_dict else i for i in l]
            l = set([x for sublist in l for x in sublist])        
            
            a = set.intersection(l, r)
            if len(set.intersection(l, r))==0:
                a = set.union(l,r)
                changes_of_state+=1
            node.var=a
#     print changes_of_state
#     print t.get_ascii(attributes=["var","id"])  
    if option == 'ACCTRAN':
        bases = acctran(t)
    elif option == 'DELTRAN':
        bases = deltran(t)
    else:
        print('ARGUMENT ISSUE')
    return bases
    

                
# t = Tree('((C,A),(C,(A,G)));', format=1)
# t = Tree('((C,A),(T,(C,C)));', format=1)
# t = Tree('((C,T),(A,(T,(A,T))));')

# %%
reconstruction_dict= {}

a = AlignIO.read("wout17/EBOV_CDS_splice_38_with_early_1610.fshift.underscores.aln.fa","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")


sequence_reconstruction= collections.defaultdict(str)
outer_id = 0
t2 = Tree("wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree",format=1)
for node in t2.traverse("postorder"):
    outer_id +=1
    sequence_reconstruction[outer_id]=''
print outer_id
    
index_dict = {}
c=0

for record in a:
    index_dict[record.id.replace('|','_')]= c
    c +=1
    
base_position = 0
for i in range(len(a[0])): 
    base_position+=1
    bp = aa[:, i:i+1] 
    bp = [i[0] for i in bp]
#     print base_position, bp
    if len(set(bp))==1:
        for k in sequence_reconstruction:
            sequence_reconstruction[k]+=bp[0].rstrip('\n')
    else:
        bases = fitch_algorithm("wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree",bp,"DELTRAN")
#         print bases
        for i in bases:
            sequence_reconstruction[i[0]]+=i[1]
            
c=0
with open("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","w") as fw:
#     fw.write('id,node_name\n')
    t = Tree("wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree",format=1)
    for node in t.traverse("postorder"):
        c+=1
#         print node
        if node.is_leaf():
            fw.write(str('>')+node.name+'\n'+sequence_reconstruction[c]+'\n')
#             node.add_features(id=node.name)
        else:
            fw.write(str('>')+str(c)+'\n'+sequence_reconstruction[c]+'\n')
            node.name=c
            
print t.get_ascii(attributes=["name"])  

t.write(format=8, outfile="wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree.node_labelled.nw")
# Out:
# 103
#
#             /-EBOV_AY354458_Zaire_Kikwit_DRC_1995
#          /7|
#         |  |   /-EBOV_JQ352763_Kikwit_Kikwit_DRC_1995-05-04
#         |   \6|
#         |     |   /-EBOV_KC242796_13625_Kikwit_DRC_1995
#         |      \5|
#         |         \-EBOV_KC242799_13709_Kikwit_DRC_1995
#       /23
#      |  |      /-EBOV_KP271020_Lomela-Lokolia19_DRC_2014-08-20
#      |  |   /10
#      |  |  |   \-EBOV_KP271018_Lomela-Lokolia16_DRC_2014-08-20
#      |  |  |
#      |  |  |      /-EBOV_KC242792_Gabon_Mekouka_Gabon_1994
#      |   \22     |
#      |     |   /17      /-EBOV_KC242795_1Mbie_Gabon_1996
#      |     |  |  |   /14
#      |     |  |   \16   \-EBOV_KC242797_1Oba_Gabon_1996
#      |      \21     |
#      |        |      \-EBOV_KC242793_1Eko_Gabon_1996
#      |        |
#      |        |   /-EBOV_KC242798_1Ikot_Gabon_1996
#      |         \20
#    /97            \-EBOV_KC242794_2Nza_Gabon_1996
#   |  |
#   |  |      /-EBOV_KC242800_Ilembe_Gabon_2002
#   |  |   /26
#   |  |  |   \-EBOV_KF113528_Kelle_1_DRC_2003
#   |  |  |
#   |  |  |               /-EBOV_HQ613403_M-M_DRC_2007-08-31
#   |  |  |            /31
#   |  |  |           |  |   /-EBOV_KC242789_Luebo4_Luebo_DRC_2007
#   |  |  |         /33   \30
#   |  |  |        |  |      \-EBOV_KC242786_Luebo1_Luebo_DRC_2007
#   |  |  |        |  |
#   |  |  |        |   \-EBOV_KC242790_Luebo5_Luebo_DRC_2007
#   |  |  |      /41
#   |  |  |     |  |      /-EBOV_KC242787_Luebo23_Luebo_DRC_2007
#   |  |  |     |  |   /36
#   |   \96     |  |  |   \-EBOV_KC242788_Luebo43_Luebo_DRC_2007
#   |     |   /43   \40
#   |     |  |  |     |   /-EBOV_HQ613402_034-KS_DRC_2008-12-31
#   |     |  |  |      \39
#   |     |  |  |         \-EBOV_KC242784_Luebo9_Luebo_DRC_2007
#   |     |  |  |
#   |     |  |   \-EBOV_KC242785_Luebo0_Luebo_DRC_2007
#   |     |  |
#   |     |  |            /-EBOV_EM_079422_KR817187_GIN_Macenta_2014-03-27
#   |     |  |         /46
#   |     |  |        |   \-EBOV_Gueckedou-C05_KJ660348_GIN_Gueckedou_2014-03-19
#   |     |  |        |
#   |     |  |      /58   /-EBOV_EM_079423_KR817188_GIN_Macenta_2014-03-27
#   |     |  |     |  |  |
#   |      \95     |  |  |      /-EBOV_EM_079421_KR817186_GIN_Macenta_2014-03-30
#   |        |     |   \57     |
#   |        |     |     |   /54      /-EBOV_EM_079414_KR817185_GIN_Gueckedou_2014-03-31
#   |        |     |     |  |  |   /51
#   |        |     |     |  |   \53   \-EBOV_EM_079413_KR817184_GIN_Gueckedou_2014-03-31
#   |        |   /66      \56     |
#   |        |  |  |        |      \-EBOV_EM_079424_KR817189_GIN_Macenta_2014-03-27
#   |        |  |  |        |
# -103       |  |  |         \-EBOV_Gueckedou-C07_KJ660347_GIN_Gueckedou_2014-03-20
#   |        |  |  |
#   |        |  |  |      /-EBOV_EM_079405_KR817180_GIN_Gueckedou_2014-03-28
#   |        |  |  |   /61
#   |        |  |  |  |   \-EBOV_EM_079408_KR817181_GIN_Gueckedou_2014-03-31
#   |         \94   \65
#   |           |     |   /-EBOV_EM_079412_KR817183_GIN_Gueckedou_2014-03-31
#   |           |      \64
#   |           |         \-EBOV_EM_079404_KR817179_GIN_Gueckedou_2014-03-28
#   |           |
#   |           |      /-EBOV_KJ660346_Kissidougou-C15_Kissidougou_Guinea_2014-03-17
#   |           |   /69
#   |           |  |   \-EBOV_Kissidougou-C15_KJ660346_GIN_Kissidougou_2014-03-17
#   |           |  |
#   |            \93   /-EBOV_EM_079410_KR817182_GIN_Gueckedou_2014-03-31
#   |              |  |
#   |              |  |   /-EBOV_KM034550_EM095_SierraLeone_EM_Kailahun_KissiTeng_2014-05-25
#   |               \92  |
#   |                 |  |   /-EBOV_CDC_Makona-201403261_Liberia_2014-09-26
#   |                 |  |  |
#   |                  \91  |         /-EBOV_KM034556_G3677_SierraLeone_G_Kailahun_KissiTeng_2014-05-26
#   |                    |  |      /75
#   |                    |  |     |   \-EBOV_KM233089_G3814_SierraLeone_G_Kailahun_Jawie_2014-06-15
#   |                    |  |     |
#   |                     \90     |      /-EBOV_KP658432_Makona-UK2_SierraLeone_Freetown_2014-12-29
#   |                       |   /87     |
#   |                       |  |  |   /82      /-EBOV_Makona-G4717.1_SierraLeone_2_2014-08-04
#   |                       |  |  |  |  |   /79
#   |                       |  |  |  |   \81   \-EBOV_Makona-G4994.1_SierraLeone_2_2014-08-14
#   |                       |  |   \86     |
#   |                        \89     |      \-EBOV_KM233112_G3851_SierraLeone_G_Kenema_Nongowa_2014-06-18
#   |                          |     |
#   |                          |     |   /-EBOV_KP260800_Manoka-Mali-DPR2_Mali_2014-11-11
#   |                          |      \85
#   |                          |         \-EBOV_KP260799_Manoka-Mali-DPR1_Mali_2014-10-22
#   |                          |
#   |                           \-EBOV_KP184503_PHE_ManoRiver-UK1.1_SierraLeone_UK_2014-08-25
#   |
#   |   /-EBOV_KC242791_Bonduni_Tandala_DRC_1977
#    \102
#      |   /-EBOV_AF272001_Mayinga_Yambuku_DRC_1976
#       \101
#          \-EBOV_KC242801_deRoover_DRC_1976

# %% [markdown]
# # SNP CLASSIFICATION

# %%
# FUNCTION DEFINITIONS #

def check_and_count(tree, old_count, snp, major_variant, minor_variant, minor_freq):
    check = minor_major_monophyly_check(tree, snp, major_variant, minor_variant, minor_freq)
    return tuple(map(lambda x, y: x + y, old_count, check))

def minor_major_monophyly_check(tree, snp, major_variant, minor_variant, minor_freq):
#     print(snp, major_variant, minor_variant)
    count = (0,0,0,0)
    if minor_freq==1:
        snp_classifier['only_occurs_once'].append((snp, major_variant+ ':'+minor_variant))
        count = (1,0,0,0)
    else:
        minor_monophyly_check = tree.check_monophyly(values=[minor_variant], target_attr="snp") 
        if minor_monophyly_check[0]:
            snp_classifier['minor_monophyly'].append((snp, major_variant+ ':'+minor_variant))
            count = (0,1,0,0)
        elif not minor_monophyly_check[0]:
            major_monophyly_check = tree.check_monophyly(values=[major_variant], target_attr="snp")
            if major_monophyly_check[0]:
                snp_classifier['major_monophyly'].append((snp, minor_variant+ ':'+major_variant))
                count = (0,0,1,0)
            elif not major_monophyly_check[0]:
                snp_classifier['not_monophyly'].append((snp, major_variant + ':'+minor_variant))
                count = (0,0,0,1)
    return count

# %%
# CREATING THE SNP DICT #
snp_dict = {}

a = AlignIO.read("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")

for i in range(len(a[0])): #for each base up to the length of the alignment
    bp = aa[:, i:i+1] 
    bases = []
    for item in bp:
        bases.append(item[0])
    c =1
    if i > 5000: #18880 for full genome
        for ambig in ['N','?','-']:
            if ambig in bases:
                c +=1
        if len(set(bases))>c:
            snp_dict['snp_'+str(i+1)]=bases
    elif 'N' in bases:
        if len(set(bases))>2:
            snp_dict['snp_'+str(i+1)]=bases
    else:
        if len(set(bases))>1:
            snp_dict['snp_'+str(i+1)]=bases

print len(snp_dict)
# Out:
# 895

# %%
# CREATING THE INDEX DICT #
# LETS YOU KNOW WHICH ITEM IN THE SNP DICT VALUE (I.E. BASES LIST) CORRESPONDS TO WHICH RECORD IN THE ALIGNMENT #
index_dict = {}
reverse_index_dict= {}
c=0
for record in a:
    index_dict[record.id]= c
    reverse_index_dict[c]=record.id
    c +=1

# %% [markdown]
# Manually add in root node name (this case 103) to the newick tree 'wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree.node_labelled.nw'

# %%
# DEFINING COUNTERS #
simple_cases_counter = 0
complex_cases_counter = 0
early_gap =0
late_gap =0
ambiguous_base=0

SIMPLE = (0,0,0,0)
COMPLEX = (0,0,0,0)

# CLASSIFYING THE SNPS #
snp_classifier = collections.defaultdict(list)

for snp in sorted(snp_dict, key= lambda x: float(x.split('_')[1])): 
    snp_count = Counter()
    t = Tree("wout17/RAxML_bipartitions.raxml_rapid_spliced_cds_tree.node_labelled.nw",format=8)
    for node in t.traverse("preorder"):
        if node.is_leaf():
            node.add_features(snp=snp_dict[snp][index_dict[node.name]])  #add snp annotations to each tip
            snp_count[snp_dict[snp][index_dict[node.name]]]+=1 #count the leaf snp frequency
    #print t.get_ascii(attributes=["snp"])  
    snp_count = snp_count.most_common()   

    major_variant = snp_count[0][0]

    # SIMPLE CASE #
    if len(snp_count)==2:
        # e.g. snp_189 [('G', 68), ('A', 4)]
        simple_cases_counter +=1 

        minor_variant = snp_count[1][0]
        minor_freq = snp_count[1][1]

        if minor_variant != 'N' and minor_variant != '?':
            SIMPLE = check_and_count(t, SIMPLE, snp, major_variant, minor_variant, minor_freq)            
    else:
        # COMPLEX CASE #
        # eg. snp_18913 [('G', 68), ('N', 3), ('A', 2), ('R', 2), ('-', 2)] #
        complex_cases_counter +=1 

        for k in snp_count[1:]:
#             print(k)
            minor_variant = k[0]
            minor_freq = k[1]

            if k[0]=='N' or k[0]=='?':
                ambiguous_base += 1
            elif float(snp.split('_')[1]) > 5000:

                new_id_list = [i for i in index_dict.keys() if i not in ['EBOV_JQ352763_Kikwit_Kikwit_DRC_1995-05-04','EBOV_HQ613403_M-M_DRC_2007-08-31','EBOV_HQ613402_034-KS_DRC_2008-12-31']]    
                t.prune(new_id_list)
                COMPLEX = check_and_count(t, COMPLEX, snp, major_variant, minor_variant, minor_freq)  
            else:
                COMPLEX = check_and_count(t, COMPLEX, snp, major_variant, minor_variant, minor_freq)

# %%
# RESULT PRINT OUT #
print '##### RESULTS #####'
print 'Simple, Complex, Total: ',simple_cases_counter, '+', complex_cases_counter,'=', simple_cases_counter+complex_cases_counter
print '\n'
print '##### SNP Classifier Dict #####'
for k in snp_classifier:
    key_dict = collections.defaultdict(list)
    for i in snp_classifier[k]:
        key_dict[i[0]].append(i[1])
    print k,'(All:', len(snp_classifier[k]), ', Unique:', len(key_dict), ')'
print '\n'    
print '##### Simple cases #####'
print '(only a single snp, minor monophyly, major monophyly, not monophyletic)'
print SIMPLE
print '\n'        
print '##### Not quite as simple cases #####'
print 'minor N or ? ', ambiguous_base
print 'early - ', early_gap
print 'late - ', late_gap
print '(only a single snp, minor monophyly, major monophyly, not monophyletic)'
print COMPLEX
print '\n'   
print '##### Tally of the two #####'
print '(', SIMPLE[0]+COMPLEX[0], SIMPLE[1]+COMPLEX[1], SIMPLE[2]+COMPLEX[2], SIMPLE[3]+COMPLEX[3], ')'
# Out:
# ##### RESULTS #####
# Simple, Complex, Total:  381 + 514 = 895
#
#
# ##### SNP Classifier Dict #####
# major_monophyly (All: 230 , Unique: 230 )
# not_monophyly (All: 40 , Unique: 40 )
# only_occurs_once (All: 116 , Unique: 114 )
# minor_monophyly (All: 522 , Unique: 520 )
#
#
# ##### Simple cases #####
# (only a single snp, minor monophyly, major monophyly, not monophyletic)
# (49, 260, 53, 19)
#
#
# ##### Not quite as simple cases #####
# minor N or ?  507
# early -  0
# late -  0
# (only a single snp, minor monophyly, major monophyly, not monophyletic)
# (67, 262, 177, 21)
#
#
# ##### Tally of the two #####
# ( 116 522 230 40 )

# %% [markdown]
# # CLUSTER ASSIGNMENT

# %%
a = AlignIO.read("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
fw = open('wout17/clustering_annotations.txt','w')
fw.write('taxa\tattrib1\n')
cluster_dict = {}
ob_dict = {}
c = 0
c2 = 0
for record in a:
    date = record.id.split('_')[-1]
    if len(record.id) > 4:
        c+=1
        date = record.id.split('_')[-1]
        if date in ['1976','1977']:
            cluster_dict[record.id]='A'
            ob_dict[record.id]='1976/1977 DRC'
            fw.write(record.id + '\tA\n')
            
        elif date.count('2014')==1 and record.id.count('Lomela')==1:
            cluster_dict[record.id]='B3'
            ob_dict[record.id]='2014 DRC'
            fw.write(record.id + '\tB3\n')
            
        elif date in ['1996','1994']:
            cluster_dict[record.id]='B1'
            ob_dict[record.id]='1994/1996 DRC'
            fw.write(record.id + '\tB1\n')
            
        elif date in ['1995','1995-05-04']:
            ob_dict[record.id]='1995 DRC'
            cluster_dict[record.id]='B2'
            fw.write(record.id + '\tB2\n')
            
        elif date.count('2014')==1:
            cluster_dict[record.id]='C'
            ob_dict[record.id]='2014-2016 WAf'
            fw.write(record.id + '\tC\n')
            
        elif date.count('2007')==1 or date.count('2008')==1:
            cluster_dict[record.id]='D'
            ob_dict[record.id]='2007 DRC'
            fw.write(record.id + '\tD\n')
            
        elif date in ['2002','2003']:
            cluster_dict[record.id]='E'
            ob_dict[record.id]='2002/2003 DRC'
            fw.write(record.id + '\tE\n')
            
#         elif date=='2017-05':
#             cluster_dict[record.id]='M'
#             fw.write(record.id + '\tM\n')
    else:
        c2 +=1
        if int(record.id) in range(101,103):
            cluster_dict[record.id]='A'
            fw.write(record.id + '\tA\n')
        
        elif record.id=='10':
            cluster_dict[record.id]='B3'
            fw.write(record.id + '\tB3\n')
        elif int(record.id) in range(14,22):
            cluster_dict[record.id]='B1'
            fw.write(record.id + '\tB1\n')
        elif int(record.id) in range(5,8):
            cluster_dict[record.id]='B2'
            fw.write(record.id + '\tB2\n')

        elif int(record.id) in range(46,95):
            cluster_dict[record.id]='C'
            fw.write(record.id + '\tC\n')
            
        elif int(record.id) in range(30,44):
            cluster_dict[record.id]='D'
            fw.write(record.id + '\tD\n')

        elif record.id=='26':
            cluster_dict[record.id]='E'
            fw.write(record.id + '\tE\n')
            
print (len(cluster_dict))


# for k in cluster_dict:
#     if cluster_dict[k] == 'D' or cluster_dict[k]=='E':
#         cluster_dict[k]='C'
# for k in cluster_dict:
#     print k, cluster_dict[k]

with open('wout17/clustering_annotations_just_the_tips.txt','w') as fw:
    fw.write('Taxa\tCluster\tDate\tYear\tOutbreak\n')
    for k in cluster_dict:
        if k.startswith('E'):
            date = k.split('_')[-1]
            if len(date)==4:
                year=date
                date = date + '-01-01'
            else:
                year = date.split('-')[0]
                
            if cluster_dict[k].startswith('B'):
                fw.write("{}\t{}\t{}\t{}\t{}\n".format(k,'B',date,year,ob_dict[k]))
            else:
                fw.write("{}\t{}\t{}\t{}\t{}\n".format(k,cluster_dict[k],date,year,ob_dict[k]))
# Out:
# 97

# %% [markdown]
# # BRANCH CLUSTER COMPARISONS

# %%
cluster_ancestral_node = {'E':'26',
                  'D':'43',
                  'C':'94',
                  'B3':'10',
                  'B1':'21',
                  'B2':'7',
                  'A':'102'}
branch_clusters={'E':'26:96',
                  'D':'43:95',
                  'C':'94:95',
                 'C:D':'95:96',
                 'C:D:E':'96:97',
                  'B3':'10:22',
                  'B1':'21:22',
                  'B2':'7:23',
                 'B1:B3':'22:23',
                 'B1:B2:B3':'23:97',
                  'A':'102:97'}
rev_branch_clusters = {}
for k in branch_clusters:
    rev_branch_clusters[branch_clusters[k]]=k

# %%
a = AlignIO.read("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")
c=0
my_cluster=collections.defaultdict(list)

branch_comparison_cluster=collections.defaultdict(list)

fw = open('wout17/branch_mutations_comparing_node_and_parent_node.csv','w')
fw.write('Clusters,SNP,Position\n')
for k in branch_clusters:
#     print k
    one = branch_clusters[k].split(':')[0]
    two = branch_clusters[k].split(':')[1]
    for record1 in a:
        for record2 in a:
            if record1.name == one and record2.name == two:
#                 print k, record1.name, record2.name
                for i in snp_classifier:
                    for j in snp_classifier[i]:
                        location = int(j[0].split('_')[1])-1
                        if record1.seq[location] != record2.seq[location]:
                            my_cluster[k].append(location)
                            #print one, two, j[1], record1.seq[location], record2.seq[location]
                            #print 'Clusters ', k, 'Base ', record1.seq[location], record2.seq[location], j
                            fw.write("{},{},{}\n".format(k,j[1],location+1))
                        
fw.close()    

fw = open('wout17/branch_mutations_counts.csv','w')
fw.write('Cluster1,Cluster2,Count\n')
fw2 = open('wout17/cluster_vs_cluster_mutations.csv','w')
fw2.write('Clusters,Position\n')
cluster_vs_cluster_dict=collections.Counter()
cluster_vs_cluster_location=collections.defaultdict(list)

for k in my_cluster:
    for j in my_cluster:
        for loc in my_cluster[k]:
            if loc in my_cluster[j]:
                cluster_vs_cluster_dict[(k,j)]+=1
                cluster_vs_cluster_location[(k,j)].append(loc)
            else:
                cluster_vs_cluster_dict[(k,j)]+=0
                
clusters = []                
for k in sorted(cluster_vs_cluster_dict):
    fw.write("{},{},{}\n".format(k[0],k[1],cluster_vs_cluster_dict[k]))
    for j in cluster_vs_cluster_location[k]:
        k = sorted(list(set(list(k))))
        
        sk = '|'.join(k)
        if sk == 'C|D':
            if j != 4212 and j!= 10979:
                fw2.write("{},{}\n".format(sk,j))
                clusters.append(sk)
        else:

            fw2.write("{},{}\n".format(sk,j))
            clusters.append(sk)
        
clusters = list(set(clusters))

print sorted(clusters)
fw.close()
fw2.close()
# Out:
# ['A', 'A|C:D', 'A|D', 'A|E', 'B1', 'B1:B2:B3', 'B1:B2:B3|C', 'B1:B2:B3|D', 'B1:B3', 'B1|B1:B2:B3', 'B1|C', 'B1|D', 'B2', 'B2|C', 'B2|D', 'B2|E', 'B3', 'B3|C', 'B3|D', 'B3|E', 'C', 'C:D', 'C:D:E', 'C:D:E|D', 'C:D|D', 'C|C:D', 'C|C:D:E', 'C|E', 'D', 'E']

# %%
a = AlignIO.read("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")
c=0
my_cluster=collections.defaultdict(list)
cluster_ancestral_dict=collections.Counter()
fw = open('wout17/branch_mutations.csv','w')
fw.write('Cluster1,Cluster2,SNP,Position\n')
for k1 in cluster_ancestral_node:
    for k2 in cluster_ancestral_node:
#     print k
        for record1 in a:
            for record2 in a:
                if record1.name == cluster_ancestral_node[k1] and record2.name == cluster_ancestral_node[k2]:
                    print k, record1.name, record2.name
# Out:
# EBOV_KC242797_1Oba_Gabon_1996 102 102
# EBOV_KC242797_1Oba_Gabon_1996 102 94
# EBOV_KC242797_1Oba_Gabon_1996 102 26
# EBOV_KC242797_1Oba_Gabon_1996 102 43
# EBOV_KC242797_1Oba_Gabon_1996 102 21
# EBOV_KC242797_1Oba_Gabon_1996 102 7
# EBOV_KC242797_1Oba_Gabon_1996 102 10
# EBOV_KC242797_1Oba_Gabon_1996 94 102
# EBOV_KC242797_1Oba_Gabon_1996 94 94
# EBOV_KC242797_1Oba_Gabon_1996 94 26
# EBOV_KC242797_1Oba_Gabon_1996 94 43
# EBOV_KC242797_1Oba_Gabon_1996 94 21
# EBOV_KC242797_1Oba_Gabon_1996 94 7
# EBOV_KC242797_1Oba_Gabon_1996 94 10
# EBOV_KC242797_1Oba_Gabon_1996 26 102
# EBOV_KC242797_1Oba_Gabon_1996 26 94
# EBOV_KC242797_1Oba_Gabon_1996 26 26
# EBOV_KC242797_1Oba_Gabon_1996 26 43
# EBOV_KC242797_1Oba_Gabon_1996 26 21
# EBOV_KC242797_1Oba_Gabon_1996 26 7
# EBOV_KC242797_1Oba_Gabon_1996 26 10
# EBOV_KC242797_1Oba_Gabon_1996 43 102
# EBOV_KC242797_1Oba_Gabon_1996 43 94
# EBOV_KC242797_1Oba_Gabon_1996 43 26
# EBOV_KC242797_1Oba_Gabon_1996 43 43
# EBOV_KC242797_1Oba_Gabon_1996 43 21
# EBOV_KC242797_1Oba_Gabon_1996 43 7
# EBOV_KC242797_1Oba_Gabon_1996 43 10
# EBOV_KC242797_1Oba_Gabon_1996 21 102
# EBOV_KC242797_1Oba_Gabon_1996 21 94
# EBOV_KC242797_1Oba_Gabon_1996 21 26
# EBOV_KC242797_1Oba_Gabon_1996 21 43
# EBOV_KC242797_1Oba_Gabon_1996 21 21
# EBOV_KC242797_1Oba_Gabon_1996 21 7
# EBOV_KC242797_1Oba_Gabon_1996 21 10
# EBOV_KC242797_1Oba_Gabon_1996 7 102
# EBOV_KC242797_1Oba_Gabon_1996 7 94
# EBOV_KC242797_1Oba_Gabon_1996 7 26
# EBOV_KC242797_1Oba_Gabon_1996 7 43
# EBOV_KC242797_1Oba_Gabon_1996 7 21
# EBOV_KC242797_1Oba_Gabon_1996 7 7
# EBOV_KC242797_1Oba_Gabon_1996 7 10
# EBOV_KC242797_1Oba_Gabon_1996 10 102
# EBOV_KC242797_1Oba_Gabon_1996 10 94
# EBOV_KC242797_1Oba_Gabon_1996 10 26
# EBOV_KC242797_1Oba_Gabon_1996 10 43
# EBOV_KC242797_1Oba_Gabon_1996 10 21
# EBOV_KC242797_1Oba_Gabon_1996 10 7
# EBOV_KC242797_1Oba_Gabon_1996 10 10

# %%
print list(j[1])[-1]
# Out:
# T

# %%
fw = open('wout17/clustering_info_EBOV.csv','w')
fw.write('Position,SNP,Cluster\n')
cluster_record = {}

for k in sorted(snp_dict, key=lambda x: int(x.split('_')[1])):
    cluster_list = []
    
    for i in reverse_index_dict:
        for j in reverse_index_dict:
            if reverse_index_dict[i] in cluster_dict and reverse_index_dict[j] in cluster_dict:
                if snp_dict[k][j] == snp_dict[k][i]:
                    cluster_list.append(cluster_dict[reverse_index_dict[i]])
                
#                     print cluster_dict[reverse_index_dict[i]]
    cluster_list = sorted(list(set(cluster_list)))
    print cluster_list
#     print sorted(cluster_list)
#     if len(cluster_list)>7 or cluster_list==[]:
#         pass
#     else:
#     if sorted(cluster_list) == ['D', 'E']:
#     print k, cluster_list
#     for j in list(set(cluster_list)):
#       print k.split('_')[1], snp_dict[k][index_dict['17EHV-0121_DRC_2017-05']], j
    j = ":".join(cluster_list)
    if j == '':
        cluster_record[k]='NA'
#     elif j == 'A:B:C:M':
#         cluster_record[k]='NA'
    else:
        cluster_record[k]=j
    for p in snp_classifier:
        for q in snp_classifier[p]:
            if q[0]==k:
                snp=q[1]
    fw.write(k.split('_')[1]+','+ snp+','+ j+'\n')


fw.close()
# for i in cluster_record:
#     print i, cluster_record[i]
# Out:
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']
# ['A', 'B1', 'B2', 'B3', 'C', 'D', 'E']

# %% [markdown]
# # SNP CLASSIFIER & CLUSTER OUTPUT

# %%
def sort_ambiguous_cases(my_ambiguous_codon):
    #Returns a list
    normal_codons = []
    for i in list(my_ambiguous_codon):
        if i not in ['A','T','G','C']:
            for j in n_dict[i]:
                new_codon= my_ambiguous_codon.replace(i,j)
                normal_codons.append(codontable[new_codon])
    if normal_codons == []:
        return codontable[my_ambiguous_codon]
    else:
        return normal_codons
    
x =sort_ambiguous_cases('GAK')
print x
# Out:
# ['E', 'D']

# %%
fw=open('wout17/identify_and_classify_snps_results.csv','w')
fw.write('Type,SNP,Major,Minor,Position,Gene,Position_in_Codon,Mutation,Cluster\n')

CNS=''
with open('wout17/ancestral_reconstruction_DELTRAN_with_names_consensus_sequence.fasta','r') as f: #fdoesn't exist
    for l in f:
        l = l.rstrip('\n')
        if l.startswith('>'):
            pass
        else:
            CNS=l
c=0
snp_type_dict = {}
for k in snp_classifier:
    for i in sorted(snp_classifier[k], key= lambda x : int(x[0].split('_')[1])):
        location = int(i[0].split('_')[1])
        codon_number = math.ceil(location/3)
        position_in_codon = (location-1)%3
        index_no = int(codon_number*3)
        codon = ''.join(CNS[index_no-3:index_no]) 
#         print codon,position_in_codon, codon[position_in_codon]
        major = codon[:position_in_codon] + i[1].split(':')[0] + codon[position_in_codon + 1:]
        minor = codon[:position_in_codon] + i[1].split(':')[1] + codon[position_in_codon + 1:]
        if major in codontable and minor in codontable:
            if codontable[major]!=codontable[minor]:
                snp_type_dict[i[0]]= 'Nonsynonymous'
            elif codontable[major]==codontable[minor]:
                snp_type_dict[i[0]]= 'Synonymous'
            mut = snp_type_dict[i[0]]
            cluster = cluster_record[i[0]]
            fw.write('{},{},{},{},{},{},{},{},{}\n'.format(k, i[1], i[1].split(':')[0], i[1].split(':')[1], location, gene[location], location%3, mut, cluster))

        else:
            pass
#             snp_type_dict[i[0]]='Synonymous'
#             #It was only a single case that is very likely synonymous
#             print '**Ambiguous cases**'
#             print k, i, location, codon
#             new_major =  sort_ambiguous_cases(major)
#             new_minor =  sort_ambiguous_cases(minor)
#             print 'major', major, new_major
#             print 'minor', minor, new_minor
            
fw.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-873c60d98580> in <module>()
#      28                 snp_type_dict[i[0]]= 'Synonymous'
#      29             mut = snp_type_dict[i[0]]
# ---> 30             cluster = cluster_record[i[0]]
#      31             fw.write('{},{},{},{},{},{},{},{},{}\n'.format(k, i[1], i[1].split(':')[0], i[1].split(':')[1], location, gene[location], location%3, mut, cluster))
#      32
#
# NameError: name 'cluster_record' is not defined

# %% [markdown]
# # ADAR EDITING?

# %%
a = AlignIO.read("wout17/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")

fw = open('wout17/t_to_c_mutations.csv','w')
fw.write('Sequence,Position\n')
fw2 = open('wout17/t_to_c_mutations_tips.csv','w')
fw2.write('Sequence,Position,Date,Cluster\n')
c=0

adar_signals=collections.defaultdict(list)

for seq in aa:
    locations_with_t_to_c=[]
    for i in snp_classifier:
        for j in sorted(snp_classifier[i], key= lambda x : int(x[0].split('_')[1])):
            if j[1] == 'T:C':
                location = int(j[0].split('_')[1])
                if seq[location-1] == 'C':
                    locations_with_t_to_c.append(location)
                    fw.write("{},{}\n".format(a[c].name,location))
                    if a[c].name.startswith('E'):
                        date = a[c].name.split('_')[-1]
                        if len(date)==4:
                            date= date+'-01-01'
                        fw2.write("{},{},{},{}\n".format(a[c].name,location,date,cluster_dict[a[c].name]))
    loc_list = sorted(locations_with_t_to_c)
    #print a[c].name, loc_list

    for k in range(0,len(loc_list)):
        quad= loc_list[k:k+4]
        if quad[-1]-quad[0]<=300:
            if len(quad) == 4:
#                 print quad, a[c].name
                adar_signals[str(quad)].append(a[c].name)
    c+=1
print len(adar_signals)
fw.close()
fw2.close()
fw = open('wout17/adar_signals.csv','w')
fw.write('Sequence,Position,Date\n')
fw2 = open('wout17/adar_signals_tips.csv','w')
fw2.write('Sequence,Position,Date,Signal,Cluster\n')

c = 0 
for i in adar_signals:
    #print '***', i, '***'
    #print set(adar_signals[i])
    c +=1
    for j in adar_signals[i]:
        for k in i.lstrip('[').rstrip(']').split(','):
#             print snp_type_dict['snp_'+str(k)]
            date = j.split('_')[-1]
            if len(date)==4:
                date= date+'-00-00'
            fw.write(j + ',' + k + ','+date+'\n')
            if j.startswith('E'):
                fw2.write("{},{},{},{},{}\n".format(j,k,date,c,cluster_dict[j]))
fw.close()
fw2.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-abb8006516a4> in <module>()
#      23                         if len(date)==4:
#      24                             date= date+'-01-01'
# ---> 25                         fw2.write("{},{},{},{}\n".format(a[c].name,location,date,cluster_dict[a[c].name]))
#      26     loc_list = sorted(locations_with_t_to_c)
#      27     #print a[c].name, loc_list
#
# NameError: name 'cluster_dict' is not defined

# %% [markdown]
# # BASE COMPOSITION ANALYSIS

# %%
def check_if_synonymous_mutation():
    position_in_codon = (location-1)%3
        index_no = int(codon_number*3)
        codon = ''.join(CNS[index_no-3:index_no]) 
#         print codon,position_in_codon, codon[position_in_codon]
        major = codon[:position_in_codon] + i[1].split(':')[0] + codon[position_in_codon + 1:]
        minor = codon[:position_in_codon] + i[1].split(':')[1] + codon[position_in_codon + 1:]
        if major in codontable and minor in codontable:
            if codontable[major]!=codontable[minor]:
                snp_type_dict[i[0]]= 'Nonsynonymous'
            elif codontable[major]==codontable[minor]:
                snp_type_dict[i[0]]= 'Synonymous'

# %%
b = AlignIO.read("wout17/1610_with_consensus_cds+ig_*gapsNotRemoved.fasta","fasta")
bb = np.array([list(rec) for rec in b], np.character, order="F")

base_content=collections.defaultdict(dict)
c=0
length_dict={}
for seq in bb:
    if 'consensus' not in b[c].name.split('_'):
        length_dict[c]=len(seq)
        base_content[b[c].name]={"One":collections.Counter(),"Two":collections.Counter(),
                                 "Three":collections.Counter(),"Intergenic":collections.Counter()}       
        location = 0
        
        for base in seq:
            location+=1
            if base!='-' and base !='?':
                if location >= 14522:
                    base_content[b[c].name]["Intergenic"][base]+=1
                elif location%3==1:
                    base_content[b[c].name]["One"][base]+=1
                elif location%3==2:
                    base_content[b[c].name]["Two"][base]+=1
                elif location%3==0:
                    base_content[b[c].name]["Three"][base]+=1        
    c+=1

# %%
fw = open('wout17/1610_base_content.csv','w')
fw.write('Sequence,Position,Base,Count,TotalAtPos,Percentage,Country,Town,Date\n')        
c = 0
for k in base_content:
    date=k.split('|')[-1]
    N_count = 0
    info = b[c].name.split('|')
    for i in base_content[k]:    
        summed = 0
        for j in base_content[k][i]:
            
            if j!='N':
                summed = summed + base_content[k][i][j]
            elif j=='N':
                N_count = N_count + base_content[k][i][j]
                
        for j in base_content[k][i]: 
            if j in ["A","T","G","C"]:
                fw.write("{},{},{},{},{},{},{},{},{}\n".format(k, i, j, base_content[k][i][j],summed,(base_content[k][i][j]/summed)*100,info[3],info[4],date))
                
    fw.write("{},{},{},{},{},{},{},{},{}\n".format(k, "Three", 'N', N_count ,length_dict[c],(N_count/length_dict[c])*100,info[3],info[4],date))

    c+=1
    
fw.close()

# %%
a = AlignIO.read("spliced_cds_work/ancestral_reconstruction_DELTRAN_with_names.fasta","fasta")
aa = np.array([list(rec) for rec in a], np.character, order="F")

base_content=collections.defaultdict(dict)
c=0
for seq in aa:
    
    if a[c].name.startswith('E'):
#     if 'consensus' not in a[c].name.split('_'):
    
        base_content[a[c].name]={"One":collections.Counter(),
                                 "Two":collections.Counter(),
                                 "Three":collections.Counter()}
        location = 0
        for base in seq:
            location+=1
            if base!='N' and base!='-' and base !='?':
                if location%3==1:
                    base_content[a[c].name]["One"][base]+=1
                elif location%3==2:
                    base_content[a[c].name]["Two"][base]+=1
                elif location%3==0:
                    base_content[a[c].name]["Three"][base]+=1
                
    c+=1
fw = open('spliced_cds_work/39_ref_base_content.csv','w')
fw.write('Sequence,Position,Base,Count,TotalAtPos,Percentage,Date\n')        
c = 0
for k in base_content:
    date=k.split('_')[-1]
    if len(date)==4:
        date = date+'-01-01'
    for i in base_content[k]:
        
        summed = 0
        for j in base_content[k][i]:
            summed = summed + base_content[k][i][j]
            c+=1
            
        for j in base_content[k][i]:
            fw.write("{},{},{},{},{},{},{}\n".format(k, i, j, base_content[k][i][j],summed,
                                                     (base_content[k][i][j]/summed)*100,
                                                     date))

fw.close()

# %% [markdown]
# # CODON USAGE ANALYSIS

# %%
b = AlignIO.read("wout17/1610_with_consensus_cds+ig_*gapsNotRemoved.fasta","fasta")
bb = np.array([list(rec) for rec in b], np.character, order="F")
c=0
codon_usage_summary = {}
codon_freq_vector = {}
for k in bb:
    if 'consensus' not in b[c].name.split('_'):
    #print len(k)
        count_list = []
        amino_acid_counter = collections.Counter()
        total_aa_count=0
        codon_usage_counter = collections.Counter()
        for triplet in range(0,14522,3):
            codon = ''.join(k[triplet:triplet+3])
            if len(codon)==3:
                if codon in codontable:
                    total_aa_count+=1
                    amino_acid_counter[codontable[codon]]+=1
                    codon_usage_counter[codon]+=1
        usage_list = []
        freq_list = []
        for i in sorted(codon_usage_counter):
            aacid=codontable[i]
            observed_count = codon_usage_counter[i]
            aa_count = amino_acid_counter[aacid]
            no_codons = no_codons_per_aa[aacid]
            E = aa_count/no_codons
            RSCU = round(codon_usage_counter[i]/E, 4)
            freq = 1000*(observed_count/total_aa_count)
            usage_list.append(RSCU)
            count_list.append((i, codon_usage_counter[i], aa_count, RSCU,total_aa_count, freq, E ))
            freq_list.append(freq)
            
        codon_usage_summary[b[c].name]=count_list
        codon_freq_vector[b[c].name]=freq_list
    c+=1
    
    
fw = open('wout17/1610_codon_usage_summary.csv','w')
fw.write('Sequence,Codon,Count,AA.Count,RSCU,Date,Total.AA.Count,freq,E\n')
for k in codon_usage_summary:
    date=k.split('|')[-1]
    for j in codon_usage_summary[k]:
        
        fw.write("{},{},{},{},{},{},{},{},{}\n".format(k, j[0],j[1],j[2],j[3],date,j[4],j[5],j[6]))

fw.close()

# %%
fw = open('wout17/1610_codon_usage_summary_with_dates.csv','w')
fw.write('Sequence,Date,Codon,Frequency,Human,Bat,Snake,One,Two,Three\n')
with open('wout17/1610_codon_usage_summary.csv','r') as f:
     for l in f:
        l = l.rstrip('\n')
        name = l.split(',')[0]
        date = name.split('|')[-1]
        tokens =  l.split(',')
        codon = tokens[1]
        if codon in human_usage_dict:
            fw.write("{},{},{},{},{},{},{},{},{},{}\n".format(tokens[0],date, codon, tokens[-2], human_usage_dict[codon],bat_usage_dict[codon], snake_usage_dict[codon],codon[0],codon[1],codon[2]))
fw.close()

# %% [markdown]
# # CODON USAGE BIAS EUCLIDEAN DISTANCE

# %%
def process_codon_usage_table(filename):
    usage_dict={}
    with open(filename,'r') as f:
        for l in f:
            l =l.rstrip('\n')
            if l.startswith('Table') or l=='':
                pass
            else:
                tokens= l.split(')')
                tokens = [i.lstrip('\xc2\xa0') for i in tokens][:-1]
                for i in tokens:
                    tokens2 = i.split('\xc2\xa0')
                    tokens2 = [i.lstrip('(') for i in tokens2 if i != ''][:-1]
                    usage_dict[tokens2[0]]= float(tokens2[1])
    print len(usage_dict)
    return usage_dict      

human_usage_dict = process_codon_usage_table('wout17/homo_sapiens_9696_codon_usage.txt')
bat_usage_dict = process_codon_usage_table('wout17/chiroptera_9397_codon_usage.txt')
snake_usage_dict = process_codon_usage_table('wout17/serpentes_8570_codon_usage.txt')

index = {}
c=0
for i in sorted(human_usage_dict):
    index[c]=i
    c+=1
# Out:
# 64
# 64
# 64

# %%
codon_freq_vector_no_stops = {}

for i in codon_freq_vector:
    new_freqs = []
    c = 0
    for j in codon_freq_vector[i]:
        if index[c] not in ['TAA','TGA','TAG']:
            new_freqs.append(j)
        else:
            new_freqs.append(1)
        c+=1
    codon_freq_vector_no_stops[i]= new_freqs

# %%
fw = open("wout17/euclidean_distance_wrt_other_sp.csv",'w')
fw.write("Sequence,Human,Bat,Snake,Date\n")

c = 0

human =[human_usage_dict[i] if i not in ['TGA','TAA','TAG'] else '1' for i in sorted(human_usage_dict) ]
human = tuple([float(i) for i in human])
bat = [bat_usage_dict[i] if i not in ['TGA','TAA','TAG'] else '1' for i in sorted(bat_usage_dict) ]
bat = tuple([float(i) for i in bat])
snake = [snake_usage_dict[i] if i not in ['TGA','TAA','TAG'] else '1' for i in sorted(snake_usage_dict) ]
snake = tuple([float(i) for i in snake])


for i in sorted(codon_freq_vector_no_stops, key = lambda x : map(int, x.split('|')[-1].split('-'))):
    c +=1
    tokens = i.split('|')
    date = tokens[-1]
    b = tuple(codon_freq_vector_no_stops[i])
    dsth = distance.euclidean(human, b)
    dstb = distance.euclidean(bat, b)
    dsts = distance.euclidean(snake, b)
    fw.write("{},{},{},{},{}\n".format(i,dsth,dstb,dsts,date))
        
fw.close()
